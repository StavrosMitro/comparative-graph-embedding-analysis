# %% [markdown]
# # GNN Experiment Pipeline: IMBD-MULTI Dataset
# Αυτό το notebook εκτελεί πείραμα για το μοντέλο GIN (GRAPH ISOMORPHISM NETWORK) χρησιμοποιώντας το dataset IMBD-MULTI.
#
# **Διαδικασία:**
# 1. Φόρτωση & Ανάλυση Δεδομένων.
# 2. Εκπαίδευση με 10-Fold Cross-Validation.
# 3. Αξιολόγηση Μοντέλου σε classification, clustering & stability analysis.
# 4. Hyperparameter Tuning (προαιρετικά).
#
# Απαραίτητη η ενεργοποίηση της GPU.

# %% [markdown]
# ## Δομή και Επεξήγηση Εξόδου (Pipeline Output)
#
# Κατά την εκτέλεση του `run_pipeline`, η διαδικασία χωρίζεται σε 4 στάδια.
#
# ### 1. Ανάλυση Δεδομένων (Dataset Analysis)
# Στην αρχή, το script φορτώνει το dataset **ENZYMES** και τυπώνει μια σύνοψη των χαρακτηριστικών του.
# * Πίνακα με `Total Graphs`, `Num Classes`, και μέσους όρους κόμβων/ακμών.
# * **Παραγόμενο Αρχείο:** `dataset_info.png` (οπτικοποίηση κατανομής κλάσεων).
#
# ### 2. Κύριο Πείραμα (Main Experiment - 10-Fold CV)
# Το σύστημα εκτελεί Cross-Validation 10 επαναλήψεων (Folds). Για κάθε Fold:
# * **Εκπαίδευση (Training):** Εμφανίζεται η πρόοδος ανά 10 εποχές με το Training Loss και το Validation Accuracy, και σε plot.
# * **Εξαγωγή Embeddings:** Μόλις ολοκληρωθεί η εκπαίδευση, το μοντέλο παράγει τα embeddings (`Saved: embeddings_fold_X.npz`).
# * **Αξιολόγηση (Evaluation):** Τα embeddings τροφοδοτούνται σε ταξινομητές (SVM, Random Forest, MLP), καθώς και εφαρμόζεται αλγόριθμος kmeans και spectral clustering. Τέλος, εμφανίζεται ένας πίνακας με τα αποτελέσματα του συγκεκριμένου Fold.
# * **Ανάλυση Σταθερότητας (Stability):** Το μοντέλο δοκιμάζεται σε δεδομένα με θόρυβο για να ελεγχθεί η ανθεκτικότητά του, και παράγονται τα αντίστοιχα αρχεία.
# * Αποθηκεύονται τα embeddings και το μοντέλο για περεταίρω ανάλυση.
#
# ### 3. Συγκεντρωτικά Αποτελέσματα (Final Aggregated Results)
# Στο τέλος της εκτέλεσης (μετά το Fold 10), τυπώνεται η ενότητα `FINAL AGGREGATED RESULTS`.
# * **Internal GNN Metrics:** Η μέση επίδοση του GIN μοντέλου (Accuracy, F1, AUC) σε όλο το Cross-Validation (Μορφή: $\text{Mean} \pm \text{Std}$).
# * **External Classifier Metrics:** Η μέση επίδοση των SVM, RF, MLP, μαζί με την τιμή του kmean ARI.
# * **Stability Metrics:** Πόσο πέφτει η ακρίβεια όταν προσθέτουμε/αφαιρούμε ακμές, μαζί με αντίστοιχα διαγράμματα.
#
# ### 4. Παραγόμενα Αρχεία
# Στο τέλος, στον φάκελο εργασίας αποθηκεύονται τα εξής αρχεία για περαιτέρω ανάλυση:
# * `experiment_results.csv`: Αναλυτικός πίνακας με όλες τις μετρήσεις για κάθε Fold ξεχωριστά.
# * `final_stats.json`: Οι μέσοι όροι και οι τυπικές αποκλίσεις σε μορφή JSON.
# * `embeddings_fold_1.npz`: 10 τέτοια αρχεία με τα embeddings από κάθε fold.
# * `model_fold_1.pth`: 10 τέτοια αρχεία με τα μοντέλα από κάθε fold.
# * `robustness_model_acc.png`: Γράφημα που δείχνει την πτώση της ακρίβειας καθώς αυξάνεται ο θόρυβος στον γράφο.
# * `resource_usage.png`: Γράφημα χρόνου εκτέλεσης και χρήσης μνήμης RAM.

# %% [markdown]
# imports

# %%
# @title
# !pip install -q torch_geometric
# !pip install -q torch_scatter torch_sparse -f https://data.pyg.org/whl/torch-2.5.1+cu124.html

import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 73.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 37.6 MB/s eta 0:00:00
# PyTorch Version: 2.9.0+cu126
# CUDA Available: True

# %%
# @title
import torch
import torch.nn.functional as F
import torch.nn as nn
import numpy as np
import os
import time
import psutil
import json
import tracemalloc
import random

from torch.nn import LazyLinear, BatchNorm1d
from torch_geometric.nn.models import GIN
from torch_geometric.nn import global_add_pool
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.utils import degree
import torch_geometric.transforms as T

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.metrics import accuracy_score, adjusted_rand_score, f1_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.pipeline import make_pipeline

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns

from sklearn.decomposition import PCA

from IPython.display import Image, display

from sklearn.model_selection import GridSearchCV

import pandas as pd

import datetime

from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE

from sklearn.preprocessing import StandardScaler
import copy
import torch.nn.init as init

import itertools
from collections import defaultdict
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_scatter/_version_cuda.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_sparse/_version_cuda.so
#   import torch_geometric.typing

# %% [markdown]
# helpers for loging time and memory usage

# %%
# @title
SCRIPT_START_TIME = time.time()

# %%
# @title
def log_status(message):
    process = psutil.Process(os.getpid())
    mem_info = process.memory_info()
    current_ram = mem_info.rss / (1024 ** 2)
    elapsed_seconds = time.time() - SCRIPT_START_TIME
    elapsed_str = str(datetime.timedelta(seconds=int(elapsed_seconds)))
    print(f"[Elapsed: {elapsed_str}] [RAM: {current_ram:.1f} MB] {message}")

# %%
# @title
class ResourceTracker:
    def __init__(self, tag=""):
        self.tag = tag
        self.start_time = None
        self.end_time = None
        self.peak_mem = 0

    def __enter__(self):
        self.start_time = time.time()
        tracemalloc.start()
        return self

    def __exit__(self, exc_type, exc_val, exc_tb):
        self.end_time = time.time()
        _, peak = tracemalloc.get_traced_memory()
        self.peak_mem = peak / (1024 * 1024)
        tracemalloc.stop()

    @property
    def duration(self):
        return self.end_time - self.start_time

    @property
    def memory_mb(self):
        return self.peak_mem

# %% [markdown]
# helpers for visualization

# %%
# @title
# ==============================================================================
# HELPER: VISUALIZATION FUNCTIONS
# ==============================================================================

def plot_dataset_info(dataset, save_path="dataset_info.png"):
    """
    Plots Class Distribution & Graph Size Statistics (Nodes/Edges).
    """
    y = [data.y.item() for data in dataset]
    classes, counts = np.unique(y, return_counts=True)

    num_nodes = [data.num_nodes for data in dataset]
    num_edges = [data.num_edges for data in dataset]

    print("\n" + "="*40)
    print("      DATASET SUMMARY")
    print("="*40)
    print(f"Total Graphs:    {len(dataset)}")
    print(f"Num Classes:     {len(classes)}")
    print(f"Avg Nodes/Graph: {np.mean(num_nodes):.2f} (Min: {min(num_nodes)}, Max: {max(num_nodes)})")
    print(f"Avg Edges/Graph: {np.mean(num_edges):.2f} (Min: {min(num_edges)}, Max: {max(num_edges)})")
    print("-" * 40)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    bars = ax1.bar(classes, counts, color='skyblue', edgecolor='black', alpha=0.8)
    ax1.set_xlabel('Class Label', fontsize=12)
    ax1.set_ylabel('Count', fontsize=12)
    ax1.set_title('Class Distribution', fontsize=14, fontweight='bold')
    ax1.grid(axis='y', linestyle='--', alpha=0.5)
    ax1.set_xticks(classes)

    for bar in bars:
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height,
                 f'{height}', ha='center', va='bottom')

    ax2.hist(num_nodes, bins=30, color='salmon', edgecolor='black', alpha=0.8)
    ax2.set_xlabel('Number of Nodes per Graph', fontsize=12)
    ax2.set_ylabel('Frequency', fontsize=12)
    ax2.set_title('Graph Size Distribution (Nodes)', fontsize=14, fontweight='bold')
    ax2.grid(axis='y', linestyle='--', alpha=0.5)
    avg_nodes = np.mean(num_nodes)
    ax2.axvline(avg_nodes, color='red', linestyle='dashed', linewidth=2, label=f'Avg: {avg_nodes:.1f}')
    ax2.legend()
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    plt.close()
    print(f"[Visuals] Saved extended dataset info to {save_path}")


def plot_final_metrics(all_results, save_path="final_performance_summary.png"):
    """
    Plots Bar Chart of Accuracy vs F1 vs AUC with Error Bars.
    """

    print("\n[Visuals] Generating Final Performance Summary Plot with Error Bars...")

    df = pd.DataFrame(all_results)
    means = df.mean().to_dict()
    stds  = df.std().to_dict()

    models = ["Internal_GIN_Val", "SVM_Lin", "SVM_RBF", "RF", "MLP"]
    labels = ["GIN (Internal)", "SVM (Linear)", "SVM (RBF)", "Random Forest", "MLP (External)"]

    acc_means = [means.get(f"{m}_Acc", 0) for m in models]
    acc_stds  = [stds.get(f"{m}_Acc", 0)  for m in models]
    f1_means  = [means.get(f"{m}_F1", 0)  for m in models]
    f1_stds   = [stds.get(f"{m}_F1", 0)   for m in models]
    auc_means = [means.get(f"{m}_AUC", 0) for m in models]
    auc_stds  = [stds.get(f"{m}_AUC", 0)  for m in models]

    x = np.arange(len(models))
    width = 0.25
    fig, ax = plt.subplots(figsize=(14, 8))

    rects1 = ax.bar(x - width, acc_means, width, yerr=acc_stds, capsize=5,
                    label='Accuracy', color='blue', edgecolor='black', alpha=0.9)

    rects2 = ax.bar(x, f1_means, width, yerr=f1_stds, capsize=5,
                    label='F1 Score', color='red', edgecolor='black', alpha=0.9)

    rects3 = ax.bar(x + width, auc_means, width, yerr=auc_stds, capsize=5,
                    label='AUC', color='green', edgecolor='black', alpha=0.9)

    ax.set_ylabel('Score (0-1)')
    title_suffix = "Results"
    ax.set_title(f'Final Model Performance (Mean ± Std Dev) Internal GIN vs. External Classifiers')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, fontsize=11)
    ax.set_ylim(0, 1.15)
    ax.legend(loc='upper right', fontsize=10)
    ax.grid(axis='y', linestyle='--', alpha=0.5)
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{height:.2f}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 5),
                        textcoords="offset points",
                        ha='center', va='bottom', fontsize=9, fontweight='bold')

    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    plt.close()
    print(f"[Visuals] Saved final summary to {save_path}")

def plot_fold_performance(final_stats, filename="fold_performance.png"):
    """
    Plots the scores of all classifiers + KMeans across all folds.
    """

    plt.figure(figsize=(14, 7))

    sample_key = next(iter(final_stats))
    num_folds = len(final_stats[sample_key])
    folds = range(1, num_folds + 1)

    styles = {
        "Internal_GIN_Val_Acc": {'marker': '*', 'label': 'GIN Internal (Val)', 'color': 'purple', 'linewidth': 2.5, 'markersize': 10},
        "SVM_Lin_Acc": {'marker': 'o', 'label': 'SVM Linear', 'color': 'tab:blue'},
        "SVM_RBF_Acc": {'marker': 's', 'label': 'SVM RBF',    'color': 'tab:orange'},
        "RF_Acc":      {'marker': '^', 'label': 'Random Forest','color': 'tab:green'},
        "MLP_Acc":     {'marker': 'd', 'label': 'MLP',        'color': 'tab:red'},
        "KMeans_ARI":  {'marker': 'x', 'label': 'KMeans (ARI)', 'color': 'black', 'linestyle': '--', 'linewidth': 2}
    }

    for name, scores in final_stats.items():
        if name in styles:
            style = styles[name]
            plt.plot(folds, scores, **style)

    plt.title(f'Classifier Accuracy & KMeans ARI per Fold ({num_folds} Folds)', fontsize=14)
    plt.xlabel('Fold Number', fontsize=12)
    plt.ylabel('Score (Accuracy / ARI)', fontsize=12)
    plt.xticks(folds)
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.savefig(filename, dpi=300)
    plt.show()
    plt.close()
    print(f"[Visuals] Saved fold performance plot: {filename}")
    return filename

def plot_fold_training_curves(train_histories, val_histories, filename="fold_training_curves.png"):
    """
    Plots Training and Validation curves side-by-side.
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6), sharey=True)

    if isinstance(train_histories, dict):
        iterator = train_histories.items()
    else:
        iterator = enumerate(train_histories)

    for fold_idx, history in iterator:
        epochs = range(1, len(history) + 1)
        ax1.plot(epochs, history, alpha=0.6, linewidth=1.5, label=f'Fold {fold_idx+1}')

    ax1.set_title('Training Accuracy per Fold')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.grid(True, linestyle='--', alpha=0.5)

    # 2. Plot Validation Curves (if provided)
    if val_histories:
        if isinstance(val_histories, dict):
            iterator = val_histories.items()
        else:
            iterator = enumerate(val_histories)

        for fold_idx, history in iterator:
            epochs = range(1, len(history) + 1)
            ax2.plot(epochs, history, alpha=0.6, linewidth=1.5, label=f'Fold {fold_idx+1}')

        ax2.set_title('Validation Accuracy per Fold')
        ax2.set_xlabel('Epochs')
        ax2.grid(True, linestyle='--', alpha=0.5)
        ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small', ncol=1)
    else:
        pass

    plt.suptitle('Learning Curves: Train vs. Validation (All Folds)', fontsize=16)
    plt.tight_layout()
    plt.savefig(filename, dpi=150)
    plt.show()
    plt.close()
    print(f"[Visuals] Saved training curves: {filename}")
    return filename

def plot_cluster_comparison(X, y_true, y_kmeans, y_spectral, save_path):
    """
    Plots 2D t-SNE embeddings thrice side-by-side:
    1. Ground Truth
    2. K-Means
    3. Spectral Clustering
    """

    print("Computing t-SNE for cluster comparison...")
    tsne = TSNE(n_components=2, perplexity=50, random_state=42, init='pca', learning_rate='auto')
    z = tsne.fit_transform(X)
    fig, axes = plt.subplots(1, 3, figsize=(24, 7))
    scatter_kwargs = {'s': 50, 'alpha': 0.8, 'edgecolors': 'w', 'linewidth': 0.2}
    # --- PLOT 1: GROUND TRUTH ---
    scatter1 = axes[0].scatter(z[:, 0], z[:, 1], c=y_true, cmap='tab10', **scatter_kwargs)
    axes[0].set_title("GT (t-SNE)", fontsize=14, fontweight='bold')
    axes[0].axis('off')
    # --- PLOT 2: K-MEANS ---
    scatter2 = axes[1].scatter(z[:, 0], z[:, 1], c=y_kmeans, cmap='tab10', **scatter_kwargs)
    axes[1].set_title("KMeans (t-SNE)", fontsize=14, fontweight='bold')
    axes[1].axis('off')
    # --- PLOT 3: SPECTRAL ---
    scatter3 = axes[2].scatter(z[:, 0], z[:, 1], c=y_spectral, cmap='tab10', **scatter_kwargs)
    axes[2].set_title("Spectral (t-SNE)", fontsize=14, fontweight='bold')
    axes[2].axis('off')
    plt.tight_layout()
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    plt.show()
    plt.close()
    print(f"[Visuals] Saved 3-panel cluster comparison to {save_path}")

def plot_stability_comparison(res_clean, res_noisy, stab_score):
    """
    Plots grouped bars for Accuracy/F1/ARI comparing Clean vs Noisy.
    """
    metrics = ['SVM_Lin_Acc', 'SVM_RBF_Acc', 'RF_Acc', 'MLP_Acc', 'KMeans_ARI']
    labels  = ['SVM (Lin)', 'SVM (RBF)', 'Random Forest', 'MLP', 'KMeans ARI']

    clean_vals = [res_clean.get(m, 0) for m in metrics]
    noisy_vals = [res_noisy.get(m, 0) for m in metrics]
    x = np.arange(len(labels))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 6))
    rects1 = ax.bar(x - width/2, clean_vals, width, label='Original', color='#2ca02c', alpha=0.8)
    rects2 = ax.bar(x + width/2, noisy_vals, width, label='Perturbed (+20% Edges)', color='#d62728', alpha=0.8)
    ax.set_ylabel('Score (0-1)')
    ax.set_title(f'Stability Analysis: Performance Drop under Noise\nEmbedding Stability Score: {stab_score:.3f}')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()
    ax.set_ylim(0, 1.15)
    ax.grid(axis='y', linestyle='--', alpha=0.5)

    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{height:.2f}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3), textcoords="offset points",
                        ha='center', va='bottom', fontsize=9)

    autolabel(rects1)
    autolabel(rects2)
    plt.tight_layout()
    save_path = "stability_comparison_plot.png"
    plt.savefig(save_path, dpi=150)
    plt.show()
    print(f"[Visuals] Saved stability comparison to {save_path}")

# %%
# @title
def plot_training_results(fold, train_acc, val_acc, train_loss, val_loss):
    epochs = range(1, len(train_acc) + 1)

    plt.figure(figsize=(12, 5))

    # Plot Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_acc, 'b-', label='Train Accuracy')
    plt.plot(epochs, val_acc, 'r-', label='Val Accuracy')
    plt.title(f'Fold {fold+1}: Training & Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_loss, 'b-', label='Train Loss')
    plt.plot(epochs, val_loss, 'r-', label='Val Loss')
    plt.title(f'Fold {fold+1}: Training & Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.savefig(f"learning_curve_fold_{fold+1}.png")
    plt.show()

# %% [markdown]
# resource visualization

# %%
# @title
def plot_resource_usage(all_results, save_path="resource_usage.png"):
    """
    Plots Training vs Generation Time with Error Bars and numeric text labels.
    """
    df = pd.DataFrame(all_results)
    means = df.mean(numeric_only=True)
    stds = df.std(numeric_only=True)

    methods = ["GIN", "SVM_Lin", "SVM_RBF", "RF", "MLP"]

    # Extract Data
    train_times = [means.get(f"{m}_Train_Time", 0) for m in methods]
    train_err   = [stds.get(f"{m}_Train_Time", 0) for m in methods]

    gen_times   = [means.get(f"{m}_Gen_Time", 0) for m in methods]
    gen_err     = [stds.get(f"{m}_Gen_Time", 0) for m in methods]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

    bars1 = ax1.bar(methods, train_times, yerr=train_err, capsize=5,
                    color='orange', edgecolor='black', alpha=0.7)

    ax1.set_title("Average Training Time (sec)", fontsize=14, fontweight='bold')
    ax1.set_ylabel("Seconds")
    ax1.grid(axis='y', linestyle='--', alpha=0.5)

    max_h1 = 0
    for rect, err in zip(bars1, train_err):
        height = rect.get_height()
        y_pos = height + err
        max_h1 = max(max_h1, y_pos)

        ax1.text(rect.get_x() + rect.get_width()/2., y_pos + (0.02 * max(train_times)),
                 f'{height:.2f}\n±{err:.2f}',
                 ha='center', va='bottom', fontsize=9, fontweight='bold', color='black')

    ax1.set_ylim(0, max_h1 * 1.25)


    bars2 = ax2.bar(methods, gen_times, yerr=gen_err, capsize=5,
                    color='teal', edgecolor='black', alpha=0.7)

    ax2.set_title("Average Generation/Inference Time (sec)", fontsize=14, fontweight='bold')
    ax2.set_ylabel("Seconds")
    ax2.grid(axis='y', linestyle='--', alpha=0.5)

    max_h2 = 0
    for rect, err in zip(bars2, gen_err):
        height = rect.get_height()
        y_pos = height + err
        max_h2 = max(max_h2, y_pos)

        ax2.text(rect.get_x() + rect.get_width()/2., y_pos + (0.02 * max(gen_times)),
                 f'{height:.3f}\n±{err:.3f}',
                 ha='center', va='bottom', fontsize=9, fontweight='bold', color='black')

    ax2.set_ylim(0, max_h2 * 1.25)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()
    print(f"[Visuals] Saved resource usage report to {save_path}")
    print("\n" + "="*70)
    print("      RESOURCE CONSUMPTION REPORT (Mean ± Std)")
    print("="*70)
    print(f"{'Method':<10} | {'Train Time (s)':<20} | {'Gen Time (s)':<20} | {'Peak RAM (MB)':<15}")
    print("-" * 75)

    def fmt(m, s): return f"{m:.2f} ± {s:.2f}"

    # GIN
    t_m = means.get('GIN_Train_Time',0); t_s = stds.get('GIN_Train_Time',0)
    g_m = means.get('GIN_Gen_Time',0);   g_s = stds.get('GIN_Gen_Time',0)
    r_m = means.get('GIN_Peak_RAM_MB',0);r_s = stds.get('GIN_Peak_RAM_MB',0)

    print(f"{'GIN':<10} | {fmt(t_m, t_s):<20} | {fmt(g_m, g_s):<20} | {fmt(r_m, r_s):<15}")

    for m in methods[1:]:
        t_m = means.get(f'{m}_Train_Time',0); t_s = stds.get(f'{m}_Train_Time',0)
        g_m = means.get(f'{m}_Gen_Time',0);   g_s = stds.get(f'{m}_Gen_Time',0)
        print(f"{m:<10} | {fmt(t_m, t_s):<20} | {fmt(g_m, g_s):<20} | {'-'}")

# %% [markdown]
# helper for picking fold with the best clustering and visualising

# %%
# @title
def best_clustering_fold(row_data, title_prefix):
        """
        Loads a specific fold's embeddings and plots the cluster comparison.
        """
        fold_idx = int(row_data['fold_idx'])
        ari_score = row_data.get(f'{title_prefix}_ARI', 0)
        if title_prefix == "Best_Performance":
             ari_score = row_data.get('MLP_Acc', 0)

        print(f">> Generating plot for {title_prefix} (Fold {fold_idx+1})...")

        try:
            data = np.load(f"embeddings_fold_{fold_idx+1}.npz")
            X_val, y_val = data['X_val'], data['y_val']

            n_classes = 3
            kmeans = KMeans(n_clusters=n_classes, n_init=20, random_state=42)
            k_labels = kmeans.fit_predict(X_val)

            spectral = SpectralClustering(n_clusters=n_classes, affinity='nearest_neighbors', random_state=42)
            s_labels = spectral.fit_predict(X_val)

            plot_cluster_comparison(
                X_val, y_val, k_labels, s_labels,
                save_path=f"best_{title_prefix.lower()}_fold_{fold_idx+1}.png"
            )
        except FileNotFoundError:
            print(f"!! Warning: Could not find embeddings for fold {fold_idx+1}. Skipping plot.")

# %% [markdown]
# helpers for stability analysis

# %%
# @title
def perturb_dataset(dataset, noise_level, mode='add'):
    """
    Perturbs the dataset by adding or removing edges.
    """
    log_status("Perturb Dataset...")
    perturbed_list = []

    for data in dataset:
        data = data.clone()
        num_edges = data.num_edges
        num_perturb = int(noise_level * num_edges)

        if mode == 'add':
            # --- ADD EDGES ---
            num_nodes = data.num_nodes
            src = torch.randint(0, num_nodes, (num_perturb,))
            dst = torch.randint(0, num_nodes, (num_perturb,))
            new_edges = torch.stack([src, dst], dim=0)
            data.edge_index = torch.cat([data.edge_index, new_edges], dim=1)

        elif mode == 'remove':
            # --- REMOVE EDGES ---
            num_perturb = min(num_perturb, num_edges)
            num_keep = num_edges - num_perturb
            if num_keep > 0:
                perm = torch.randperm(num_edges)
                keep_indices = perm[:num_keep]
                data.edge_index = data.edge_index[:, keep_indices]
            else:
                data.edge_index = torch.empty((2, 0), dtype=torch.long)

        perturbed_list.append(data)

    return perturbed_list

# %% [markdown]
# plot stability analysis results

# %%
# @title
def plot_stability_summary(df_results, save_path="final_stability_dual_plot.png"):
    """
    Creates a side-by-side bar chart showing:
    1. Model Accuracy vs Noise
    2. Cosine Similarity vs Noise
    *NOW INCLUDES DATA LABELS ON BARS*
    """
    print(f">> Generating Dual Stability Summary Plot to {save_path}...")

    master_csv = "stability_detailed_ALL_FOLDS.csv"
    if not os.path.exists(master_csv):
        print(f"!! WARNING: {master_csv} not found. Cannot plot Cosine Similarity.")
        return

    df_detailed = pd.read_csv(master_csv)

    plot_df = df_detailed[df_detailed['Mode'] != 'Clean'].copy()

    plot_df['Mode'] = plot_df['Mode'].str.lower()

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
    sns.set_style("whitegrid")

    palette = {"add": "green", "remove": "red"}

    bar1 = sns.barplot(
        data=plot_df,
        x="Noise_Level", y="Model_Accuracy", hue="Mode",
        ax=ax1, palette=palette, capsize=.1, edgecolor='k', errorbar='sd'
    )
    ax1.set_title("Robustness: Model Accuracy (Mean ± Std)", fontsize=14, fontweight='bold')
    ax1.set_ylabel("Accuracy Score")
    ax1.set_xlabel("Noise Level")
    ax1.set_ylim(0, 1.15)

    bar2 = sns.barplot(
        data=plot_df,
        x="Noise_Level", y="Cosine_Similarity", hue="Mode",
        ax=ax2, palette=palette, capsize=.1, edgecolor='k', errorbar='sd'
    )
    ax2.set_title("Stability: Embedding Cosine Similarity (Mean ± Std)", fontsize=14, fontweight='bold')
    ax2.set_ylabel("Similarity (Relative to Clean)")
    ax2.set_xlabel("Noise Level")
    ax2.set_ylim(0.9, 1.02)

    def add_labels(ax, decimals=4):
        for container in ax.containers:

            try:
                ax.bar_label(container, fmt=f'%.{decimals}f', padding=3, fontsize=9, fontweight='bold')
            except AttributeError:
                for rect in container:
                    height = rect.get_height()
                    if height > 0:
                        ax.text(
                            rect.get_x() + rect.get_width() / 2,
                            height,
                            f"{height:.{decimals}f}",
                            ha='center', va='bottom',
                            fontsize=9, fontweight='bold'
                        )

    add_labels(ax1, decimals=2)
    add_labels(ax2, decimals=4)

    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()
    print(f"[Plots] Saved dual stability plot to {save_path}")

# %%
# @title
def plot_robustness_curve(df_detailed, metric="Model_Accuracy", save_path="robustness_curve.png", ylabel="Score"):
    """
    Plots the degradation of a specific metric Model_Accuracy as noise increases.
    """

    print(f">> Generating Robustness Curve for {metric}...")
    if df_detailed.empty:
        print("!! Dataframe is empty. Skipping robustness curve.")
        return

    df_clean = df_detailed[df_detailed['Mode'] == 'Clean'].copy()
    df_add   = df_detailed[df_detailed['Mode'] == 'add'].copy()
    df_rem   = df_detailed[df_detailed['Mode'] == 'remove'].copy()

    clean_add = df_clean.copy()
    clean_add['Mode'] = 'add'

    clean_rem = df_clean.copy()
    clean_rem['Mode'] = 'remove'

    df_plot = pd.concat([clean_add, clean_rem, df_add, df_rem], ignore_index=True)

    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")

    palette = {"add": "green", "remove": "red"}


    sns.lineplot(
        data=df_plot,
        x="Noise_Level",
        y=metric,
        hue="Mode",
        palette=palette,
        style="Mode",
        markers=True,
        dashes=False,
        linewidth=2.5,
        errorbar='sd'
    )

    plt.title(f"Model Robustness: {metric} vs. Structural Noise", fontsize=14, fontweight='bold')
    plt.xlabel("Noise Level (Ratio of Edges)", fontsize=12)
    plt.ylabel(f"{metric} Score", fontsize=12)

    vals = df_plot['Noise_Level'].unique()
    plt.xticks(vals, [f"{int(x*100)}%" for x in sorted(vals)])

    plt.legend(title="Perturbation Type", loc='lower left')

    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()
    plt.close()
    print(f"[Plots] Saved robustness curve to {save_path}")

# %% [markdown]
# Plot hyperparameter tradeoff

# %%
# @title
def plot_tuning_results(results_dict, save_path="tuning_tradeoff.png"):
    """Plots Accuracy vs Compute Cost (Time) for different dimensions."""
    dims = results_dict["dim"]
    accs = [x * 100 for x in results_dict["accuracy"]]
    times = results_dict["training_time"]

    fig, ax1 = plt.subplots(figsize=(10, 6))

    color = 'tab:blue'
    ax1.set_xlabel('Embedding Dimension', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Validation Accuracy (%)', color=color, fontsize=12, fontweight='bold')
    ax1.plot(dims, accs, color=color, marker='o', linewidth=3, label='Accuracy')
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.grid(True, alpha=0.3)

    ax2 = ax1.twinx()
    color = 'tab:red'
    ax2.set_ylabel('Training Time (s)', color=color, fontsize=12, fontweight='bold')
    ax2.plot(dims, times, color=color, marker='s', linestyle='--', linewidth=2, label='Compute Cost')
    ax2.tick_params(axis='y', labelcolor=color)

    plt.title('Hyperparameter Tuning:\nAccuracy vs. Compute Cost', fontsize=14)
    plt.xticks(dims)
    fig.tight_layout()
    plt.savefig(save_path)
    plt.show()
    plt.close()
    print(f"[Plot] Saved tuning tradeoff to {save_path}")

# %% [markdown]
# # GIN IMPLEMENTATION

# %% [markdown]
# *GIN_CONFIG: Προτείνεται από το paper https://arxiv.org/pdf/1810.00826 για social networks όπως το IMBD.*

# %%
# ==============================================================================
# GLOBAL HYPERPARAMETERS
# ==============================================================================
GIN_CONFIG = {
    # Model Architecture
    "hidden_channels": 64,
    "num_layers": 5,
    "dropout": 0.5,
    "train_eps": True,

    # Training
    "lr": 0.01,
    "weight_decay": 1e-4,
    "step_size": 50,
    "gamma": 0.5
}

# %%
# ==============================================================================
# 1. GIN MODEL
# ==============================================================================
class GINModel(torch.nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super().__init__()

        dim        = kwargs.get("hidden_dim", GIN_CONFIG["hidden_channels"])
        num_layers = kwargs.get("num_layers", GIN_CONFIG["num_layers"])
        dropout    = kwargs.get("dropout",    GIN_CONFIG["dropout"])
        train_eps  = kwargs.get("train_eps",  GIN_CONFIG["train_eps"])

        # Paper Specs: Sum Pooling, JK=Cat, train_eps trainable
        self.gin = GIN(
            in_channels=in_channels,
            hidden_channels=dim,
            num_layers=num_layers,
            dropout=dropout,
            norm=BatchNorm1d(dim),
            jk="cat",
            train_eps=train_eps
        )
        # Internal Head for Supervised Training
        #self.internal_head = LazyLinear(out_channels)
        input_dim = dim
        self.internal_head = torch.nn.Sequential(
            torch.nn.Linear(input_dim, dim),
            torch.nn.BatchNorm1d(dim),
            torch.nn.ReLU(),
            torch.nn.Dropout(p=0.5),
            torch.nn.Linear(dim, out_channels)   # Final Prediction
        )

    def get_embedding(self, x, edge_index, batch):

      node_embeddings = self.gin(x, edge_index)
      #all_node_feats = torch.cat([x, node_embeddings], dim=-1)
      graph_emb = global_add_pool(node_embeddings, batch)
      return graph_emb

    def forward(self, x, edge_index, batch):
        """Forward pass for Adam Optimizer"""
        emb = self.get_embedding(x, edge_index, batch)
        #return self.internal_head(emb)
        return emb

# %% [markdown]
# Train and save

# %%
# @title
# ==============================================================================
# 2. TRAIN LOOP
# ==============================================================================

def train_and_save(fold_idx, train_loader, val_loader, dataset, device, filename, hyperparams=None):
    """
    Trains a gin model with Early Stopping and saves embeddings from the best epoch.
    """

    stats = {}
    log_status(f"--- Fold {fold_idx+1}: Initializing GIN ---")

    if hyperparams is None: hyperparams = {}

    # 1. Initialize Model
    model = GINModel(dataset.num_features, dataset.num_classes, **hyperparams).to(device)

    learning_rate = hyperparams.get("lr", GIN_CONFIG["lr"])
    w_decay = hyperparams.get("weight_decay", GIN_CONFIG["weight_decay"])

    # 2. Optimizer & Scheduler
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=w_decay)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=GIN_CONFIG["step_size"], gamma=GIN_CONFIG["gamma"])

    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    #     optimizer,
    #     T_max=350,
    #     eta_min=0.0001
    # )

    log_status("Starting Training Loop...")
    with ResourceTracker("GIN_Train") as rt_train:

      # 3. Training Config
      MAX_EPOCHS = 150
      # TRY NO EARLY STOPPING BUT STILL KEEP BEST MODEL OUT OF EVERY EPOCH
      # patience = 30
      # patience_counter = 0

      # 4. State Tracking for Best Model
      best_val_loss = float('inf')
      best_model_wts = copy.deepcopy(model.state_dict())
      best_epoch = 0

      # List to store training accuracy per epoch
      train_acc_history = []
      val_acc_history = []
      train_loss_history = []
      val_loss_history = []

      # --- MAIN LOOP ---
      for epoch in range(1, MAX_EPOCHS + 1):
          # --- TRAIN STEP ---
          model.train()
          total_loss = 0
          total_correct = 0
          total_examples = 0

          for data in train_loader:
              data = data.to(device)
              optimizer.zero_grad()

              # Forward pass
              out = model(data.x, data.edge_index, data.batch)
              loss = F.cross_entropy(out, data.y)

              # Backward pass
              loss.backward()
              optimizer.step()
              total_loss += loss.item()

              pred = out.argmax(dim=1)
              total_correct += int((pred == data.y).sum())
              total_examples += data.y.size(0)

          scheduler.step()
          avg_train_loss = total_loss / len(train_loader)

          epoch_train_acc = total_correct / total_examples if total_examples > 0 else 0
          train_acc_history.append(epoch_train_acc)
          train_loss_history.append(avg_train_loss)

          # --- VALIDATION STEP (Run EVERY epoch) ---
          model.eval()
          val_loss = 0
          correct = 0
          total = 0

          with torch.no_grad():
              for data in val_loader:
                  data = data.to(device)
                  out = model(data.x, data.edge_index, data.batch)

                  # Track Loss
                  val_loss += F.cross_entropy(out, data.y).item()

                  # Track Accuracy
                  pred = out.argmax(dim=1)
                  correct += (pred == data.y).sum().item()
                  total += data.y.size(0)

          avg_val_loss = val_loss / len(val_loader)
          val_acc = correct / total if total > 0 else 0

          val_acc_history.append(val_acc)
          val_loss_history.append(avg_val_loss)

          if avg_val_loss < best_val_loss:
              best_val_loss = avg_val_loss
              best_model_wts = copy.deepcopy(model.state_dict())
              best_epoch = epoch
              # patience_counter = 0
          # else:
          #     patience_counter += 1

          # --- LOGGING ---
          if epoch % 10 == 0:
              # log_status(f"Epoch {epoch:03d} | Train: {avg_train_loss:.4f} | Val: {avg_val_loss:.4f} (Acc: {val_acc:.4f}) | Patience: {patience_counter}/{patience}")
              log_status(f"Epoch {epoch:03d} | Train: {avg_train_loss:.4f} | Val: {avg_val_loss:.4f} (Acc: {val_acc:.4f})")

          # --- EARLY STOPPING TRIGGER ---
          # if patience_counter >= patience:
          #     log_status(f"Early stopping triggered at Epoch {epoch}. Best model was Epoch {best_epoch}.")
          #     break

    log_status("Training finished.")
    stats["GIN_Train_Time"] = rt_train.duration
    stats["GIN_Peak_RAM_MB"] = rt_train.memory_mb

    # --- RESTORE BEST WEIGHTS ---
    log_status(f"Restoring best model from Epoch {best_epoch} with Val Loss {best_val_loss:.4f}")
    model.load_state_dict(best_model_wts)

    # --- FINAL METRIC CALCULATION (ACC, F1, AUC) ---
    model.eval()
    all_preds = []
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for data in val_loader:
            data = data.to(device)
            logits = model(data.x, data.edge_index, data.batch)
            probs = F.softmax(logits, dim=1)  # Probabilities for AUC
            preds = logits.argmax(dim=1)      # Hard labels for Acc/F1

            all_preds.append(preds.cpu())
            all_probs.append(probs.cpu())
            all_labels.append(data.y.cpu())

    y_true = torch.cat(all_labels).numpy()
    y_pred = torch.cat(all_preds).numpy()
    y_probs = torch.cat(all_probs).numpy()

    final_acc = accuracy_score(y_true, y_pred)
    final_f1 = f1_score(y_true, y_pred, average='weighted') # Handles class imbalance

    try:
        if dataset.num_classes == 2:
            final_auc = roc_auc_score(y_true, y_probs[:, 1])
        else:
            final_auc = roc_auc_score(y_true, y_probs, multi_class='ovr', average='weighted')
    except ValueError:
        final_auc = 0.5
    print(f"\n[Fold {fold_idx+1} FINAL RESULTS]")
    print(f"   > Best Val Acc: {final_acc*100:.2f}%")
    print(f"   > F1-Score:     {final_f1:.4f}")
    print(f"   > AUC:          {final_auc:.4f}")
    print("-" * 40)

    stats["Internal_GIN_Val_Acc"] = final_acc
    stats["Internal_GIN_Val_F1"] = final_f1
    stats["Internal_GIN_Val_AUC"] = final_auc

    # --- SAVE MODEL ---
    weight_path = f"model_fold_{fold_idx+1}.pth"
    torch.save(model.state_dict(), weight_path)

    # --- EXTRACT EMBEDDINGS ---
    def extract(loader):
        vecs, labels = [], []
        model.eval()
        with torch.no_grad():
            for data in loader:
                data = data.to(device)
                emb = model.get_embedding(data.x, data.edge_index, data.batch)
                vecs.append(emb.detach().cpu().numpy())
                labels.append(data.y.cpu().numpy())
        return np.concatenate(vecs), np.concatenate(labels)

    log_status("Extracting embeddings...")

    with ResourceTracker("GIN_Gen") as rt_gen:
      X_train, y_train = extract(train_loader)
      X_val, y_val = extract(val_loader)

    stats["GIN_Gen_Time"] = rt_gen.duration
    print(f"   > Generated Embedding Dimensions: {X_train.shape}")

    # --- SAVE EMBEDDINGS ---
    np.savez(filename, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val)
    log_status(f"Saved: {filename}")

    plot_training_results(fold_idx, train_acc_history, val_acc_history, train_loss_history, val_loss_history)

    return filename, train_acc_history, val_acc_history, model, stats

# %% [markdown]
# Evaluate classifiers

# %%
# @title
# ==============================================================================
# 3. EVALUATION
# ==============================================================================
def evaluate_classifiers(filename, fold_idx, n_classes=3):
    log_status(f"Loading '{filename}' for Evaluation...")
    data = np.load(filename)
    X_train, y_train = data['X_train'], data['y_train']
    X_val, y_val     = data['X_val'], data['y_val']

    results = {}

    # ==========================================================================
    # SUPERVISED CLASSIFIERS
    # ==========================================================================

    classifiers = {
        "SVM_Lin": make_pipeline(StandardScaler(), SVC(kernel='linear', probability=True, max_iter=10000)),
        "SVM_RBF": make_pipeline(StandardScaler(), SVC(kernel='rbf', probability=True, max_iter=10000)),
        "RF":      RandomForestClassifier(n_estimators=50, n_jobs=1, random_state=42),
        "MLP":     make_pipeline(StandardScaler(), MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42))
    }

    print(f"\n   [Fold {fold_idx+1} Evaluation]")
    print(f"   {'Model':<10} | {'Acc':<8} | {'F1':<8} | {'AUC':<8} | {'Time(s)':<8}")
    print("   " + "-"*60)

    for name, model in classifiers.items():

        clean_name = name.strip()

        with ResourceTracker() as rt_train:
            try:
              model.fit(X_train, y_train)
            except Exception as e:
              print(f"   !! Error training {name}: {e}")
              continue
        results[f"{clean_name}_Train_Time"] = rt_train.duration

        with ResourceTracker() as rt_gen:
            pred = model.predict(X_val)
            # PROBABILITIES REQUIRED FOR AUC
            prob = model.predict_proba(X_val)
        results[f"{clean_name}_Gen_Time"] = rt_gen.duration

        # Acc and F1
        acc = accuracy_score(y_val, pred)
        f1  = f1_score(y_val, pred, average='weighted')

        # AUC
        try:
            auc = roc_auc_score(y_val, prob, multi_class='ovr', average='weighted')
        except ValueError:
            auc = 0.5

        results[f"{clean_name}_Acc"] = acc
        results[f"{clean_name}_F1"]  = f1
        results[f"{clean_name}_AUC"] = auc
        print(f"   {clean_name:<10} | {acc*100:.1f}%   | {f1*100:.1f}%   | {auc:.3f}    | {rt_train.duration:.2f}s")

    # ==========================================================================
    # UNSUPERVISED: K-Means
    # ==========================================================================
    kmeans = KMeans(n_clusters=n_classes, n_init=20, random_state=42)
    kmeans_labels = kmeans.fit_predict(X_val)

    kmeans_ari = adjusted_rand_score(y_val, kmeans_labels)
    results["KMeans_ARI"] = kmeans_ari
    print(f"   >> KMeans ARI: {kmeans_ari:.4f}")

    # ==========================================================================
    # UNSUPERVISED: Spectral Clustering
    # ==========================================================================
    spectral = SpectralClustering(n_clusters=n_classes,
                                  affinity='nearest_neighbors',
                                  random_state=42,
                                  n_neighbors=10)
    spectral_labels = spectral.fit_predict(X_val)
    spectral_ari = adjusted_rand_score(y_val, spectral_labels)
    results["Spectral_ARI"] = spectral_ari
    print(f"   >> Spectral ARI: {spectral_ari:.4f}")
    print("   " + "="*60 + "\n")

    # ==========================================================================
    # VISUALIZATION ONLY FOR FOLD 0
    # ==========================================================================
    if fold_idx == 0:
        plot_cluster_comparison(
            X_val,
            y_val,
            kmeans_labels,
            spectral_labels,
            save_path="pca_cluster_comparison_fold_1.png"
        )

    return results

# %% [markdown]
# Stability analysis

# %%
# @title
def run_stability_analysis(dataset, device, fold_idx, model=None, model_path=None):
    """
    Comprehensive Stability Analysis:
    - Calculates Cosine Similarity between Clean and Noisy validation sets.
    - Evaluates downstream performance on noisy data.
    - Saves a detailed CSV for this fold.
    - Returns summary_stats for main pipeline aggregation.
    """

    print(f"\n>> ] Running Analysis for Fold {fold_idx+1}...")

    # Load Model from current fold
    if model is not None:
        model.eval()
    elif model_path:
        print(f"   Loading model weights from {model_path}...")
        model = GINModel(dataset.num_features, dataset.num_classes).to(device)
        model.load_state_dict(torch.load(model_path))
        model.eval()
    else:
        raise ValueError("Must provide model object or model_path")

    # 2. Redo split so data are the same
    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    y_all = [data.y.item() for data in dataset]
    _, val_idx = list(kfold.split(dataset, y_all))[fold_idx]

    val_ds_clean = dataset[torch.tensor(val_idx)]
    val_loader_clean = DataLoader(val_ds_clean, batch_size=32, shuffle=False)

    def get_metrics(loader):
        vecs = []
        correct = 0
        total = 0

        with torch.no_grad():
            for data in loader:
                data = data.to(device)

                # Get Embeddings
                emb = model.get_embedding(data.x, data.edge_index, data.batch)
                vecs.append(emb.detach().cpu().numpy())

                # Get Predictions
                out = model(data.x, data.edge_index, data.batch)
                pred = out.argmax(dim=1)

                correct += int((pred == data.y).sum())
                total += data.y.size(0)

        accuracy = correct / total if total > 0 else 0
        return np.concatenate(vecs), accuracy

    # Clean baseline
    X_val_clean, acc_clean = get_metrics(val_loader_clean)
    print(f"   > Clean Baseline Acc: {acc_clean*100:.2f}%")

    # Stability tests -> 8 cases
    noise_modes = ['add', 'remove']
    noise_levels = [0.05, 0.1, 0.15, 0.20]

    summary_stats = {'add': {}, 'remove': {}}
    csv_records = []

    csv_records.append({
        "Fold": fold_idx + 1,
        "Mode": "Clean",
        "Noise_Level": 0.0,
        "Cosine_Similarity": 1.0,
        "Model_Accuracy": acc_clean
    })


    for mode in noise_modes:
        for level in noise_levels:

            # Perturb
            val_ds_noisy = perturb_dataset(val_ds_clean, noise_level=level, mode=mode)
            val_loader_noisy = DataLoader(val_ds_noisy, batch_size=32, shuffle=False)

            # Get noisy metrics
            X_val_noisy, acc_noisy = get_metrics(val_loader_noisy)

            # Cosine Similarity
            cos_sims = cosine_similarity(X_val_clean, X_val_noisy).diagonal()
            avg_cos_sim = float(np.mean(cos_sims))

            # Store in summary_stats using the mode directly
            summary_stats[mode][level] = acc_noisy

            # Add to CSV records
            csv_records.append({
                "Fold": fold_idx + 1,
                "Mode": mode,
                "Noise_Level": level,
                "Cosine_Similarity": avg_cos_sim,
                "Model_Accuracy": acc_noisy
            })

    # 6. Save Detailed CSV
    df_fold = pd.DataFrame(csv_records)
    csv_filename = f"stability_fold_{fold_idx+1}_detailed.csv"
    df_fold.to_csv(csv_filename, index=False)

    print(f"\n   [Fold {fold_idx+1} Stability Report]")
    print(f"   {'Mode':<10} | {'Noise':<8} | {'Acc':<8} | {'CosSim':<8}")
    print("   " + "-"*40)
    print(f"   {'Clean':<10} | {'0%':<8} | {acc_clean:.4f}   | 1.0000")

    for row in csv_records[1:]:
        print(f"   {row['Mode']:<10} | {int(row['Noise_Level']*100)}%      | {row['Model_Accuracy']:.4f}   | {row['Cosine_Similarity']:.4f}")
    print("   " + "-"*40 + "\n")

    return summary_stats

# %%
# ==============================================================================
# MAIN PIPELINE
# ==============================================================================
def run_pipeline(
    run_dataset_analysis=True,
    run_main_experiment=True,
    enable_stability=True,
    run_hyperparameter_tuning=False,
    n_folds=10
):
    print("STARTING PIPELINE")

    SCRIPT_START_TIME = time.time()

    # --------------------------------------------------------------------------
    # 1. DATASET LOADING + PLOTTING
    # --------------------------------------------------------------------------

    print(f"Loading {DATASET_NAME} with One-Hot Degree...")
    # Pre-load to find max degree needed for one-hot
    temp_ds = TUDataset(root='data/TUDataset', name=DATASET_NAME)
    max_degree = 0
    for data in temp_ds:
      d = degree(data.edge_index[0], dtype=torch.long)
      max_degree = max(max_degree, d.max().item())
    transform = T.OneHotDegree(max_degree)
    dataset = TUDataset(root='data/TUDataset', name=DATASET_NAME, transform=transform).shuffle()

    if run_dataset_analysis:
      print("\nRunning Dataset Analysis & Plotting...")
      plot_dataset_info(dataset)
      print(f"Dataset Features: {dataset.num_features} (Input Dimension)")

    # --------------------------------------------------------------------------
    # 2. PREPARE K-FOLD CV
    # --------------------------------------------------------------------------
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    if run_main_experiment:
      print(f"Starting Main Experiment ({n_folds}-Fold CV)...")
      kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)
      y_all = [data.y.item() for data in dataset]

      fold_train_histories = {}
      fold_val_histories = {}
      fold_metrics_lists = defaultdict(list)
      all_fold_results = []

      # --------------------------------------------------------------------------
      # 3. TRAINING LOOP
      # --------------------------------------------------------------------------

      for fold, (train_idx, val_idx) in enumerate(kfold.split(dataset, y_all)):
          print(f"\n{'='*40}")
          print(f"STARTING FOLD {fold+1}/10")

          train_ds = dataset[torch.tensor(train_idx)]
          val_ds   = dataset[torch.tensor(val_idx)]
          train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
          val_loader   = DataLoader(val_ds, batch_size=32, shuffle=False)

          filename = f"embeddings_fold_{fold+1}.npz"

          saved_file, train_hist, val_hist, trained_model, gin_stats = train_and_save(fold, train_loader, val_loader, dataset, device, filename)
          fold_train_histories[fold] = train_hist
          fold_val_histories[fold] = val_hist

          # Evaluate Classifiers & Clustering
          fold_scores = evaluate_classifiers(saved_file, fold, n_classes=dataset.num_classes)

          full_fold_result = {**fold_scores, **gin_stats}
          full_fold_result['fold_idx'] = fold

          # Do stability analysis
          if enable_stability:
            print(f">> Running Stability Analysis for Fold {fold+1}...")
            stability_stats = run_stability_analysis(dataset, device, fold_idx=fold, model=trained_model)

            for mode, levels in stability_stats.items():
              for level, score in levels.items():
                col_name = f"Stab_{mode.capitalize()}_{int(level*100)}"
                full_fold_result[col_name] = score

          all_fold_results.append(full_fold_result)
          for key, value in full_fold_result.items():
            if isinstance(value, (int, float)):
              fold_metrics_lists[key].append(value)

    # --------------------------------------------------------------------------
    # 4. AGGREGATE RESULTS & SAVE
    # --------------------------------------------------------------------------
    if run_main_experiment:
      print("\n" + "="*60)
      print("FINAL AGGREGATED RESULTS")
      print("="*60)

      df_results = pd.DataFrame(all_fold_results)

      cols = list(df_results.columns)
      priority_cols = ['fold_idx', 'Internal_GIN_Val_Acc', 'Internal_GIN_Val_F1', 'Internal_GIN_Val_AUC']

      priority_cols = [c for c in priority_cols if c in cols]
      other_cols = [c for c in cols if c not in priority_cols]
      df_results = df_results[priority_cols + other_cols]

      # Raw results to CSV
      csv_filename = f"experiment_results.csv"
      df_results.to_csv(csv_filename, index=False)
      print(f"[Data] Saved per-fold results to {csv_filename}")

      final_stats = {
        "mean": df_results.mean().to_dict(),
        "std": df_results.std().to_dict()
      }

      print(f"\n--- INTERNAL GNN METRICS  ---")
      for metric in ['Internal_GIN_Val_Acc', 'Internal_GIN_Val_F1', 'Internal_GIN_Val_AUC']:
          if metric in final_stats['mean']:
              m = final_stats['mean'][metric]
              s = final_stats['std'][metric]
              print(f"{metric:<25}: {m:.4f} ± {s:.4f}")
      print("-" * 40)

      print(f"--- EXTERNAL CLASSIFIER METRICS ---")
      for col in df_results.columns:
        if col not in priority_cols and col in final_stats['mean']:
           mean_val = final_stats['mean'][col]
           std_val  = final_stats['std'][col]
           print(f"{col: <25}: {mean_val:.4f} ± {std_val:.4f}")

      # Save stats to JSON
      json_filename = f"final_stats.json"
      with open(json_filename, 'w') as f:
        json.dump(final_stats, f, indent=4)
      print(f"[Data] Saved summary stats to {json_filename}")

    # --------------------------------------------------------------------------
    # 5. PLOTS
    # --------------------------------------------------------------------------

      plot_final_metrics(all_fold_results, f"final_performance.png")
      plot_resource_usage(all_fold_results)
      plot_fold_training_curves(fold_train_histories, fold_val_histories, "fold_training_curves.png")
      plot_fold_performance(fold_metrics_lists)
      if enable_stability:
        plot_stability_summary(df_results, "final_stability_bar_chart.png")

    # --------------------------------------------------------------------------
    # 6. MERGE DETAILED STABILITY REPORTS & PLOT ROBUSTNESS
    # --------------------------------------------------------------------------
    if (run_dataset_analysis and enable_stability):
      print("\n>> Merging detailed stability reports...")
      stability_frames = []
      for f_idx in range(10):
        fname = f"stability_fold_{f_idx+1}_detailed.csv"
        if os.path.exists(fname):
          stability_frames.append(pd.read_csv(fname))

      if stability_frames:
        df_stability_all = pd.concat(stability_frames, ignore_index=True)
        master_csv = "stability_detailed_ALL_FOLDS.csv"
        df_stability_all.to_csv(master_csv, index=False)
        print(f"[Data] Saved master stability file: {master_csv}")


        # 1. Plot Accuracy Drop
        if 'Model_Accuracy' in df_stability_all.columns:
            plot_robustness_curve(
                df_stability_all,
                metric="Model_Accuracy",
                save_path="robustness_model_acc.png",
                ylabel="GIN Model Accuracy"
            )

        # 2. Plot Cosine Similarity
        if 'Cosine_Similarity' in df_stability_all.columns:
            plot_robustness_curve(
                df_stability_all,
                metric="Cosine_Similarity",
                save_path="robustness_cosine_sim.png",
                ylabel="Avg Cosine Similarity"
            )

    # --------------------------------------------------------------------------
    # 7. HYPERPARAMETER TUNING
    # --------------------------------------------------------------------------
    if run_hyperparameter_tuning:
        print("\n" + "="*60)
        print("STARTING HYPERPARAMETER TUNING (Embedding Dimension)")
        print("="*60)

        embedding_dims = [16, 32, 64, 128, 256]
        tuning_results = {"dim": [], "accuracy": [], "f1": [], "training_time": []}


        skf_tune = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
        y_all = [data.y.item() for data in dataset]
        train_idx, val_idx = next(skf_tune.split(dataset, y_all))

        tune_train_loader = DataLoader(dataset[torch.tensor(train_idx)], batch_size=32, shuffle=True)
        tune_val_loader   = DataLoader(dataset[torch.tensor(val_idx)], batch_size=32, shuffle=False)

        for dim in embedding_dims:
            print(f"\n»»» Testing Hidden Dimension: {dim} «««")

            temp_filename = f"tuning_dim_{dim}.npz"

            tune_params = {"hidden_dim": dim, "lr": 0.01, "dropout": 0.5}

            _, _, _, _, tune_stats = train_and_save(
                fold_idx=999,
                train_loader=tune_train_loader,
                val_loader=tune_val_loader,
                dataset=dataset,
                device=device,
                filename=temp_filename,
                hyperparams=tune_params
            )

            tuning_results["dim"].append(dim)
            tuning_results["accuracy"].append(tune_stats["Internal_GIN_Val_Acc"])
            tuning_results["f1"].append(tune_stats["Internal_GIN_Val_F1"])
            tuning_results["training_time"].append(tune_stats["GIN_Train_Time"])

            if os.path.exists(temp_filename):
                os.remove(temp_filename)

        pd.DataFrame(tuning_results).to_csv("tuning_results.csv", index=False)
        plot_tuning_results(tuning_results, "tuning_tradeoff_plot.png")
        print("\n[Tuning] Completed. Check 'tuning_tradeoff_plot.png'.")



    print(f"\nPipeline Finished in {(time.time() - SCRIPT_START_TIME)/60:.2f} minutes.")

# %%
# ==============================================================================
# CONFIGURATION
# ==============================================================================
DATASET_NAME = 'IMDB-MULTI'
run_pipeline(run_dataset_analysis=True, run_main_experiment=True, enable_stability=True, run_hyperparameter_tuning=False, n_folds=10)
# Out:
# STARTING PIPELINE
# Loading IMDB-MULTI with One-Hot Degree...
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/IMDB-MULTI.zip
# Processing...
# Done!
# Running Dataset Analysis & Plotting...
#
# ========================================
#       DATASET SUMMARY
# ========================================
# Total Graphs:    1500
# Num Classes:     3
# Avg Nodes/Graph: 13.00 (Min: 7, Max: 89)
# Avg Edges/Graph: 131.87 (Min: 24, Max: 2934)
# ----------------------------------------
# [Visuals] Saved extended dataset info to dataset_info.png
# Dataset Features: 89 (Input Dimension)
# Starting Main Experiment (10-Fold CV)...
#
# ========================================
# STARTING FOLD 1/10
# [Elapsed: 0:00:07] [RAM: 920.9 MB] --- Fold 1: Initializing GIN ---
# [Elapsed: 0:00:08] [RAM: 1035.4 MB] Starting Training Loop...
# [Elapsed: 0:00:31] [RAM: 1464.0 MB] Epoch 010 | Train: 1.6365 | Val: 1.7108 (Acc: 0.4467)
# [Elapsed: 0:00:41] [RAM: 1464.1 MB] Epoch 020 | Train: 1.0384 | Val: 3.2217 (Acc: 0.4733)
# [Elapsed: 0:00:51] [RAM: 1464.2 MB] Epoch 030 | Train: 1.0058 | Val: 1.1421 (Acc: 0.3933)
# [Elapsed: 0:01:00] [RAM: 1464.3 MB] Epoch 040 | Train: 0.9516 | Val: 1.7920 (Acc: 0.4133)
# [Elapsed: 0:01:09] [RAM: 1464.4 MB] Epoch 050 | Train: 1.0103 | Val: 2.9498 (Acc: 0.4000)
# [Elapsed: 0:01:19] [RAM: 1464.4 MB] Epoch 060 | Train: 0.9250 | Val: 1.8422 (Acc: 0.4733)
# [Elapsed: 0:01:29] [RAM: 1464.5 MB] Epoch 070 | Train: 0.9090 | Val: 2.1011 (Acc: 0.4667)
# [Elapsed: 0:01:39] [RAM: 1464.5 MB] Epoch 080 | Train: 0.8940 | Val: 11.7231 (Acc: 0.4667)
# [Elapsed: 0:01:50] [RAM: 1464.5 MB] Epoch 090 | Train: 0.8898 | Val: 10.0456 (Acc: 0.4400)
# [Elapsed: 0:01:59] [RAM: 1464.5 MB] Epoch 100 | Train: 0.8774 | Val: 9.0423 (Acc: 0.4600)
# [Elapsed: 0:02:09] [RAM: 1464.6 MB] Epoch 110 | Train: 0.8625 | Val: 3.7374 (Acc: 0.4333)
# [Elapsed: 0:02:19] [RAM: 1464.7 MB] Epoch 120 | Train: 0.8635 | Val: 9.8780 (Acc: 0.4333)
# [Elapsed: 0:02:29] [RAM: 1464.7 MB] Epoch 130 | Train: 0.8703 | Val: 1.2252 (Acc: 0.4933)
# [Elapsed: 0:02:38] [RAM: 1464.8 MB] Epoch 140 | Train: 0.8411 | Val: 10.5688 (Acc: 0.4667)
# [Elapsed: 0:02:48] [RAM: 1464.8 MB] Epoch 150 | Train: 0.8370 | Val: 5.5553 (Acc: 0.4867)
# [Elapsed: 0:02:58] [RAM: 1464.8 MB] Epoch 160 | Train: 0.8311 | Val: 4.7129 (Acc: 0.4867)
# [Elapsed: 0:03:09] [RAM: 1464.8 MB] Epoch 170 | Train: 0.8424 | Val: 2.5436 (Acc: 0.4533)
# [Elapsed: 0:03:19] [RAM: 1464.8 MB] Epoch 180 | Train: 0.8103 | Val: 10.3466 (Acc: 0.4600)
# [Elapsed: 0:03:28] [RAM: 1464.9 MB] Epoch 190 | Train: 0.8085 | Val: 6.6550 (Acc: 0.4600)
# [Elapsed: 0:03:38] [RAM: 1464.9 MB] Epoch 200 | Train: 0.8182 | Val: 4.1170 (Acc: 0.4600)
# [Elapsed: 0:03:47] [RAM: 1464.9 MB] Epoch 210 | Train: 0.8089 | Val: 3.1519 (Acc: 0.4467)
# [Elapsed: 0:03:57] [RAM: 1464.9 MB] Epoch 220 | Train: 0.8141 | Val: 2.3608 (Acc: 0.4600)
# [Elapsed: 0:04:07] [RAM: 1464.9 MB] Epoch 230 | Train: 0.7964 | Val: 2.6384 (Acc: 0.4733)
# [Elapsed: 0:04:16] [RAM: 1464.9 MB] Epoch 240 | Train: 0.8001 | Val: 1.7228 (Acc: 0.4533)
# [Elapsed: 0:04:25] [RAM: 1464.9 MB] Epoch 250 | Train: 0.7767 | Val: 2.9208 (Acc: 0.4533)
# [Elapsed: 0:04:35] [RAM: 1464.9 MB] Epoch 260 | Train: 0.7795 | Val: 1.5560 (Acc: 0.4533)
# [Elapsed: 0:04:45] [RAM: 1465.0 MB] Epoch 270 | Train: 0.7812 | Val: 2.3451 (Acc: 0.4533)
# [Elapsed: 0:04:54] [RAM: 1465.0 MB] Epoch 280 | Train: 0.7812 | Val: 1.1435 (Acc: 0.4600)
# [Elapsed: 0:05:04] [RAM: 1465.0 MB] Epoch 290 | Train: 0.7777 | Val: 1.1553 (Acc: 0.4600)
# [Elapsed: 0:05:13] [RAM: 1465.0 MB] Epoch 300 | Train: 0.7730 | Val: 1.6453 (Acc: 0.4533)
# [Elapsed: 0:05:23] [RAM: 1465.0 MB] Epoch 310 | Train: 0.7825 | Val: 1.7362 (Acc: 0.4400)
# [Elapsed: 0:05:33] [RAM: 1465.0 MB] Epoch 320 | Train: 0.8180 | Val: 1.2203 (Acc: 0.4467)
# [Elapsed: 0:05:42] [RAM: 1465.0 MB] Epoch 330 | Train: 0.7726 | Val: 1.2791 (Acc: 0.4467)
# [Elapsed: 0:05:52] [RAM: 1465.0 MB] Epoch 340 | Train: 0.7820 | Val: 1.1821 (Acc: 0.4400)
# [Elapsed: 0:06:01] [RAM: 1465.0 MB] Epoch 350 | Train: 0.7742 | Val: 1.1922 (Acc: 0.4467)
# [Elapsed: 0:06:01] [RAM: 1465.0 MB] Training finished.
# [Elapsed: 0:06:01] [RAM: 1465.0 MB] Restoring best model from Epoch 38 with Val Loss 0.9966
#
# [Fold 1 FINAL RESULTS]
#    > Best Val Acc: 47.33%
#    > F1-Score:     0.4742
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:06:01] [RAM: 1474.0 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:06:02] [RAM: 1474.0 MB] Saved: embeddings_fold_1.npz
# [Elapsed: 0:06:03] [RAM: 1478.2 MB] Loading 'embeddings_fold_1.npz' for Evaluation...
#
#    [Fold 1 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 36.7%   | 25.1%   | 0.617    | 0.59s
#    SVM_RBF    | 44.0%   | 42.0%   | 0.629    | 0.68s
#    RF         | 48.7%   | 48.1%   | 0.628    | 0.78s
#    MLP        | 42.7%   | 41.0%   | 0.597    | 2.18s
#    >> KMeans ARI: -0.0001
#    >> Spectral ARI: 0.0293
#    ============================================================
#
# Computing t-SNE for cluster comparison...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# [Visuals] Saved 3-panel cluster comparison to pca_cluster_comparison_fold_1.png
# >> Running Stability Analysis for Fold 1...
#
# >> ] Running Analysis for Fold 1...
#    > Clean Baseline Acc: 47.33%
# [Elapsed: 0:06:09] [RAM: 1496.2 MB] Perturb Dataset...
# [Elapsed: 0:06:09] [RAM: 1496.8 MB] Perturb Dataset...
# [Elapsed: 0:06:09] [RAM: 1496.9 MB] Perturb Dataset...
# [Elapsed: 0:06:09] [RAM: 1496.9 MB] Perturb Dataset...
# [Elapsed: 0:06:09] [RAM: 1497.0 MB] Perturb Dataset...
# [Elapsed: 0:06:10] [RAM: 1497.0 MB] Perturb Dataset...
# [Elapsed: 0:06:10] [RAM: 1497.0 MB] Perturb Dataset...
# [Elapsed: 0:06:10] [RAM: 1497.0 MB] Perturb Dataset...
#
#    [Fold 1 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.4733   | 1.0000
#    add        | 5%      | 0.4667   | 0.9989
#    add        | 10%      | 0.4667   | 0.9977
#    add        | 15%      | 0.4600   | 0.9970
#    add        | 20%      | 0.4267   | 0.9966
#    remove     | 5%      | 0.4733   | 0.9998
#    remove     | 10%      | 0.4733   | 0.9989
#    remove     | 15%      | 0.4733   | 0.9968
#    remove     | 20%      | 0.4867   | 0.9961
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 2/10
# [Elapsed: 0:06:10] [RAM: 1497.5 MB] --- Fold 2: Initializing GIN ---
# [Elapsed: 0:06:10] [RAM: 1497.6 MB] Starting Training Loop...
# [Elapsed: 0:06:20] [RAM: 1497.7 MB] Epoch 010 | Train: 1.3976 | Val: 1.1112 (Acc: 0.4867)
# [Elapsed: 0:06:30] [RAM: 1497.7 MB] Epoch 020 | Train: 1.2625 | Val: 0.9717 (Acc: 0.4667)
# [Elapsed: 0:06:40] [RAM: 1497.7 MB] Epoch 030 | Train: 1.0139 | Val: 0.9713 (Acc: 0.5000)
# [Elapsed: 0:06:49] [RAM: 1497.7 MB] Epoch 040 | Train: 0.9473 | Val: 0.9972 (Acc: 0.4867)
# [Elapsed: 0:06:59] [RAM: 1497.7 MB] Epoch 050 | Train: 0.9543 | Val: 0.9740 (Acc: 0.4600)
# [Elapsed: 0:07:09] [RAM: 1497.7 MB] Epoch 060 | Train: 0.9143 | Val: 0.9575 (Acc: 0.4800)
# [Elapsed: 0:07:19] [RAM: 1497.7 MB] Epoch 070 | Train: 0.8915 | Val: 0.9606 (Acc: 0.4667)
# [Elapsed: 0:07:29] [RAM: 1497.7 MB] Epoch 080 | Train: 0.8970 | Val: 0.9718 (Acc: 0.4800)
# [Elapsed: 0:07:39] [RAM: 1497.7 MB] Epoch 090 | Train: 0.8977 | Val: 1.0430 (Acc: 0.4733)
# [Elapsed: 0:07:48] [RAM: 1497.7 MB] Epoch 100 | Train: 0.8861 | Val: 0.9738 (Acc: 0.4867)
# [Elapsed: 0:07:58] [RAM: 1497.7 MB] Epoch 110 | Train: 0.8629 | Val: 0.9960 (Acc: 0.4800)
# [Elapsed: 0:08:08] [RAM: 1497.7 MB] Epoch 120 | Train: 0.8557 | Val: 1.0211 (Acc: 0.4733)
# [Elapsed: 0:08:18] [RAM: 1497.7 MB] Epoch 130 | Train: 0.8640 | Val: 1.0786 (Acc: 0.4733)
# [Elapsed: 0:08:28] [RAM: 1497.7 MB] Epoch 140 | Train: 0.8529 | Val: 1.0114 (Acc: 0.4800)
# [Elapsed: 0:08:37] [RAM: 1497.7 MB] Epoch 150 | Train: 0.8669 | Val: 1.0920 (Acc: 0.4667)
# [Elapsed: 0:08:47] [RAM: 1497.7 MB] Epoch 160 | Train: 0.8417 | Val: 1.1354 (Acc: 0.4600)
# [Elapsed: 0:08:57] [RAM: 1497.7 MB] Epoch 170 | Train: 0.8355 | Val: 1.0591 (Acc: 0.4733)
# [Elapsed: 0:09:07] [RAM: 1497.7 MB] Epoch 180 | Train: 0.8281 | Val: 1.0592 (Acc: 0.4667)
# [Elapsed: 0:09:17] [RAM: 1497.7 MB] Epoch 190 | Train: 0.8235 | Val: 1.1150 (Acc: 0.4733)
# [Elapsed: 0:09:27] [RAM: 1497.7 MB] Epoch 200 | Train: 0.8019 | Val: 1.1023 (Acc: 0.4667)
# [Elapsed: 0:09:36] [RAM: 1497.7 MB] Epoch 210 | Train: 0.7934 | Val: 1.1522 (Acc: 0.4733)
# [Elapsed: 0:09:46] [RAM: 1497.7 MB] Epoch 220 | Train: 0.8011 | Val: 1.1447 (Acc: 0.4733)
# [Elapsed: 0:09:56] [RAM: 1497.7 MB] Epoch 230 | Train: 0.7924 | Val: 1.0790 (Acc: 0.4867)
# [Elapsed: 0:10:06] [RAM: 1497.7 MB] Epoch 240 | Train: 0.7938 | Val: 1.1147 (Acc: 0.4667)
# [Elapsed: 0:10:16] [RAM: 1497.7 MB] Epoch 250 | Train: 0.7891 | Val: 1.1431 (Acc: 0.4667)
# [Elapsed: 0:10:25] [RAM: 1497.7 MB] Epoch 260 | Train: 0.8011 | Val: 1.5528 (Acc: 0.4667)
# [Elapsed: 0:10:35] [RAM: 1497.7 MB] Epoch 270 | Train: 0.7952 | Val: 1.9025 (Acc: 0.4667)
# [Elapsed: 0:10:45] [RAM: 1497.7 MB] Epoch 280 | Train: 0.7910 | Val: 1.4402 (Acc: 0.4667)
# [Elapsed: 0:10:56] [RAM: 1497.7 MB] Epoch 290 | Train: 0.7835 | Val: 1.5577 (Acc: 0.4733)
# [Elapsed: 0:11:06] [RAM: 1497.7 MB] Epoch 300 | Train: 0.7879 | Val: 1.1674 (Acc: 0.4733)
# [Elapsed: 0:11:16] [RAM: 1497.7 MB] Epoch 310 | Train: 0.7779 | Val: 1.3020 (Acc: 0.4733)
# [Elapsed: 0:11:26] [RAM: 1497.7 MB] Epoch 320 | Train: 0.7938 | Val: 1.1403 (Acc: 0.4800)
# [Elapsed: 0:11:36] [RAM: 1497.7 MB] Epoch 330 | Train: 0.7848 | Val: 1.1315 (Acc: 0.4800)
# [Elapsed: 0:11:46] [RAM: 1497.7 MB] Epoch 340 | Train: 0.7810 | Val: 1.1376 (Acc: 0.4733)
# [Elapsed: 0:11:56] [RAM: 1497.7 MB] Epoch 350 | Train: 0.7852 | Val: 1.1259 (Acc: 0.4800)
# [Elapsed: 0:11:56] [RAM: 1497.7 MB] Training finished.
# [Elapsed: 0:11:56] [RAM: 1497.7 MB] Restoring best model from Epoch 52 with Val Loss 0.9473
#
# [Fold 2 FINAL RESULTS]
#    > Best Val Acc: 46.67%
#    > F1-Score:     0.4572
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:11:56] [RAM: 1498.6 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:11:57] [RAM: 1498.6 MB] Saved: embeddings_fold_2.npz
# [Elapsed: 0:11:58] [RAM: 1498.7 MB] Loading 'embeddings_fold_2.npz' for Evaluation...
#
#    [Fold 2 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 34.0%   | 23.0%   | 0.541    | 0.52s
#    SVM_RBF    | 31.3%   | 30.6%   | 0.487    | 0.69s
#    RF         | 45.3%   | 44.4%   | 0.652    | 0.80s
#    MLP        | 31.3%   | 31.0%   | 0.502    | 1.00s
#    >> KMeans ARI: -0.0021
#    >> Spectral ARI: -0.0034
#    ============================================================
#
# >> Running Stability Analysis for Fold 2...
#
# >> ] Running Analysis for Fold 2...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 46.67%
# [Elapsed: 0:12:01] [RAM: 1498.7 MB] Perturb Dataset...
# [Elapsed: 0:12:01] [RAM: 1498.7 MB] Perturb Dataset...
# [Elapsed: 0:12:02] [RAM: 1498.7 MB] Perturb Dataset...
# [Elapsed: 0:12:02] [RAM: 1498.7 MB] Perturb Dataset...
# [Elapsed: 0:12:02] [RAM: 1498.7 MB] Perturb Dataset...
# [Elapsed: 0:12:02] [RAM: 1498.7 MB] Perturb Dataset...
# [Elapsed: 0:12:02] [RAM: 1498.7 MB] Perturb Dataset...
# [Elapsed: 0:12:02] [RAM: 1498.7 MB] Perturb Dataset...
#
#    [Fold 2 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.4667   | 1.0000
#    add        | 5%      | 0.4667   | 0.9999
#    add        | 10%      | 0.4800   | 0.9993
#    add        | 15%      | 0.4533   | 0.9984
#    add        | 20%      | 0.4600   | 0.9979
#    remove     | 5%      | 0.5067   | 0.9999
#    remove     | 10%      | 0.5200   | 0.9993
#    remove     | 15%      | 0.5133   | 0.9986
#    remove     | 20%      | 0.5067   | 0.9984
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 3/10
# [Elapsed: 0:12:02] [RAM: 1498.7 MB] --- Fold 3: Initializing GIN ---
# [Elapsed: 0:12:03] [RAM: 1498.7 MB] Starting Training Loop...
# [Elapsed: 0:12:13] [RAM: 1498.7 MB] Epoch 010 | Train: 1.7413 | Val: 1.0765 (Acc: 0.5267)
# [Elapsed: 0:12:23] [RAM: 1498.7 MB] Epoch 020 | Train: 1.0791 | Val: 1.3026 (Acc: 0.4600)
# [Elapsed: 0:12:33] [RAM: 1498.7 MB] Epoch 030 | Train: 1.0336 | Val: 5.0901 (Acc: 0.5067)
# [Elapsed: 0:12:44] [RAM: 1498.7 MB] Epoch 040 | Train: 0.9533 | Val: 2.2882 (Acc: 0.4933)
# [Elapsed: 0:12:54] [RAM: 1498.7 MB] Epoch 050 | Train: 0.9717 | Val: 6.0408 (Acc: 0.4867)
# [Elapsed: 0:13:04] [RAM: 1498.7 MB] Epoch 060 | Train: 0.9214 | Val: 5.3393 (Acc: 0.5533)
# [Elapsed: 0:13:14] [RAM: 1498.7 MB] Epoch 070 | Train: 0.8983 | Val: 10.5682 (Acc: 0.5133)
# [Elapsed: 0:13:24] [RAM: 1498.7 MB] Epoch 080 | Train: 0.9545 | Val: 4.5506 (Acc: 0.5200)
# [Elapsed: 0:13:34] [RAM: 1498.8 MB] Epoch 090 | Train: 0.9443 | Val: 8.6145 (Acc: 0.5000)
# [Elapsed: 0:13:44] [RAM: 1498.8 MB] Epoch 100 | Train: 0.9092 | Val: 1.6561 (Acc: 0.5400)
# [Elapsed: 0:13:54] [RAM: 1498.8 MB] Epoch 110 | Train: 0.8836 | Val: 5.5897 (Acc: 0.5333)
# [Elapsed: 0:14:04] [RAM: 1498.8 MB] Epoch 120 | Train: 0.8785 | Val: 1.4911 (Acc: 0.5133)
# [Elapsed: 0:14:14] [RAM: 1498.8 MB] Epoch 130 | Train: 0.8797 | Val: 4.0511 (Acc: 0.5000)
# [Elapsed: 0:14:23] [RAM: 1498.8 MB] Epoch 140 | Train: 0.8760 | Val: 6.8429 (Acc: 0.5133)
# [Elapsed: 0:14:34] [RAM: 1498.8 MB] Epoch 150 | Train: 0.8633 | Val: 4.4931 (Acc: 0.5333)
# [Elapsed: 0:14:44] [RAM: 1498.8 MB] Epoch 160 | Train: 0.8376 | Val: 0.9928 (Acc: 0.5333)
# [Elapsed: 0:14:54] [RAM: 1498.8 MB] Epoch 170 | Train: 0.8293 | Val: 5.0317 (Acc: 0.5200)
# [Elapsed: 0:15:03] [RAM: 1498.8 MB] Epoch 180 | Train: 0.8437 | Val: 7.4831 (Acc: 0.5400)
# [Elapsed: 0:15:13] [RAM: 1498.8 MB] Epoch 190 | Train: 0.8216 | Val: 4.3785 (Acc: 0.5067)
# [Elapsed: 0:15:23] [RAM: 1498.8 MB] Epoch 200 | Train: 0.8388 | Val: 17.5523 (Acc: 0.5133)
# [Elapsed: 0:15:33] [RAM: 1498.8 MB] Epoch 210 | Train: 0.8043 | Val: 7.3901 (Acc: 0.5000)
# [Elapsed: 0:15:43] [RAM: 1498.8 MB] Epoch 220 | Train: 0.7945 | Val: 22.1670 (Acc: 0.5133)
# [Elapsed: 0:15:53] [RAM: 1498.8 MB] Epoch 230 | Train: 0.8018 | Val: 1.3019 (Acc: 0.5067)
# [Elapsed: 0:16:03] [RAM: 1498.8 MB] Epoch 240 | Train: 0.8107 | Val: 5.4511 (Acc: 0.4733)
# [Elapsed: 0:16:13] [RAM: 1498.8 MB] Epoch 250 | Train: 0.8101 | Val: 1.1469 (Acc: 0.5067)
# [Elapsed: 0:16:23] [RAM: 1498.8 MB] Epoch 260 | Train: 0.7966 | Val: 1.2578 (Acc: 0.5067)
# [Elapsed: 0:16:33] [RAM: 1498.8 MB] Epoch 270 | Train: 0.7892 | Val: 1.1567 (Acc: 0.5200)
# [Elapsed: 0:16:43] [RAM: 1498.8 MB] Epoch 280 | Train: 0.7738 | Val: 1.7515 (Acc: 0.4867)
# [Elapsed: 0:16:53] [RAM: 1498.8 MB] Epoch 290 | Train: 0.7911 | Val: 1.1672 (Acc: 0.5000)
# [Elapsed: 0:17:03] [RAM: 1498.8 MB] Epoch 300 | Train: 0.7759 | Val: 1.2086 (Acc: 0.5267)
# [Elapsed: 0:17:13] [RAM: 1498.8 MB] Epoch 310 | Train: 0.7747 | Val: 1.1975 (Acc: 0.5000)
# [Elapsed: 0:17:23] [RAM: 1498.8 MB] Epoch 320 | Train: 0.7858 | Val: 1.2207 (Acc: 0.5267)
# [Elapsed: 0:17:33] [RAM: 1498.8 MB] Epoch 330 | Train: 0.8054 | Val: 1.2280 (Acc: 0.5200)
# [Elapsed: 0:17:44] [RAM: 1498.8 MB] Epoch 340 | Train: 0.7918 | Val: 1.2162 (Acc: 0.5333)
# [Elapsed: 0:17:54] [RAM: 1498.8 MB] Epoch 350 | Train: 0.7711 | Val: 1.1965 (Acc: 0.5267)
# [Elapsed: 0:17:54] [RAM: 1498.8 MB] Training finished.
# [Elapsed: 0:17:54] [RAM: 1498.8 MB] Restoring best model from Epoch 117 with Val Loss 0.9211
#
# [Fold 3 FINAL RESULTS]
#    > Best Val Acc: 56.00%
#    > F1-Score:     0.5556
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:17:54] [RAM: 1498.8 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:17:55] [RAM: 1498.8 MB] Saved: embeddings_fold_3.npz
# [Elapsed: 0:17:55] [RAM: 1498.8 MB] Loading 'embeddings_fold_3.npz' for Evaluation...
#
#    [Fold 3 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 39.3%   | 29.4%   | 0.638    | 0.60s
#    SVM_RBF    | 37.3%   | 37.4%   | 0.554    | 0.67s
#    RF         | 51.3%   | 51.3%   | 0.713    | 0.81s
#    MLP        | 36.7%   | 36.9%   | 0.534    | 1.22s
#    >> KMeans ARI: 0.0139
#    >> Spectral ARI: 0.0061
#    ============================================================
#
# >> Running Stability Analysis for Fold 3...
#
# >> ] Running Analysis for Fold 3...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 56.00%
# [Elapsed: 0:17:59] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:17:59] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:17:59] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:17:59] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:17:59] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:17:59] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:17:59] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:17:59] [RAM: 1498.8 MB] Perturb Dataset...
#
#    [Fold 3 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.5600   | 1.0000
#    add        | 5%      | 0.5533   | 1.0000
#    add        | 10%      | 0.5533   | 1.0000
#    add        | 15%      | 0.5400   | 1.0000
#    add        | 20%      | 0.5467   | 0.9987
#    remove     | 5%      | 0.5333   | 1.0000
#    remove     | 10%      | 0.5267   | 0.9997
#    remove     | 15%      | 0.5467   | 0.9980
#    remove     | 20%      | 0.5333   | 0.9966
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 4/10
# [Elapsed: 0:18:00] [RAM: 1498.8 MB] --- Fold 4: Initializing GIN ---
# [Elapsed: 0:18:00] [RAM: 1498.8 MB] Starting Training Loop...
# [Elapsed: 0:18:10] [RAM: 1498.8 MB] Epoch 010 | Train: 1.5705 | Val: 1.0731 (Acc: 0.4133)
# [Elapsed: 0:18:20] [RAM: 1498.8 MB] Epoch 020 | Train: 1.0572 | Val: 0.9663 (Acc: 0.4467)
# [Elapsed: 0:18:30] [RAM: 1498.8 MB] Epoch 030 | Train: 0.9933 | Val: 0.9336 (Acc: 0.5333)
# [Elapsed: 0:18:40] [RAM: 1498.8 MB] Epoch 040 | Train: 0.9516 | Val: 4.2185 (Acc: 0.4733)
# [Elapsed: 0:18:49] [RAM: 1498.8 MB] Epoch 050 | Train: 0.9292 | Val: 7.8885 (Acc: 0.4867)
# [Elapsed: 0:18:59] [RAM: 1498.8 MB] Epoch 060 | Train: 0.9003 | Val: 1.0343 (Acc: 0.4800)
# [Elapsed: 0:19:10] [RAM: 1498.8 MB] Epoch 070 | Train: 0.9187 | Val: 1.0423 (Acc: 0.4533)
# [Elapsed: 0:19:20] [RAM: 1498.8 MB] Epoch 080 | Train: 0.8871 | Val: 1.1368 (Acc: 0.4667)
# [Elapsed: 0:19:30] [RAM: 1498.8 MB] Epoch 090 | Train: 0.9241 | Val: 1.0825 (Acc: 0.4600)
# [Elapsed: 0:19:40] [RAM: 1498.8 MB] Epoch 100 | Train: 0.8893 | Val: 6.9159 (Acc: 0.4467)
# [Elapsed: 0:19:50] [RAM: 1498.8 MB] Epoch 110 | Train: 0.8558 | Val: 1.9506 (Acc: 0.4333)
# [Elapsed: 0:20:00] [RAM: 1498.8 MB] Epoch 120 | Train: 0.8498 | Val: 3.0070 (Acc: 0.4733)
# [Elapsed: 0:20:10] [RAM: 1498.8 MB] Epoch 130 | Train: 0.8523 | Val: 3.0285 (Acc: 0.4667)
# [Elapsed: 0:20:21] [RAM: 1498.8 MB] Epoch 140 | Train: 0.8280 | Val: 19.9715 (Acc: 0.4533)
# [Elapsed: 0:20:31] [RAM: 1498.8 MB] Epoch 150 | Train: 0.8250 | Val: 2.7382 (Acc: 0.4467)
# [Elapsed: 0:20:41] [RAM: 1498.8 MB] Epoch 160 | Train: 0.8149 | Val: 4.9450 (Acc: 0.4533)
# [Elapsed: 0:20:50] [RAM: 1498.8 MB] Epoch 170 | Train: 0.8184 | Val: 11.0704 (Acc: 0.4533)
# [Elapsed: 0:21:00] [RAM: 1498.8 MB] Epoch 180 | Train: 0.8305 | Val: 9.2229 (Acc: 0.4533)
# [Elapsed: 0:21:10] [RAM: 1498.8 MB] Epoch 190 | Train: 0.8088 | Val: 1.1983 (Acc: 0.4733)
# [Elapsed: 0:21:20] [RAM: 1498.8 MB] Epoch 200 | Train: 0.8157 | Val: 1.2047 (Acc: 0.4667)
# [Elapsed: 0:21:30] [RAM: 1498.8 MB] Epoch 210 | Train: 0.7863 | Val: 1.2196 (Acc: 0.4600)
# [Elapsed: 0:21:40] [RAM: 1498.8 MB] Epoch 220 | Train: 0.8223 | Val: 1.2611 (Acc: 0.4733)
# [Elapsed: 0:21:50] [RAM: 1498.8 MB] Epoch 230 | Train: 0.7929 | Val: 1.2640 (Acc: 0.4667)
# [Elapsed: 0:22:00] [RAM: 1498.8 MB] Epoch 240 | Train: 0.7777 | Val: 1.3168 (Acc: 0.4600)
# [Elapsed: 0:22:10] [RAM: 1498.8 MB] Epoch 250 | Train: 0.7935 | Val: 1.3335 (Acc: 0.4733)
# [Elapsed: 0:22:20] [RAM: 1498.8 MB] Epoch 260 | Train: 0.7733 | Val: 1.3448 (Acc: 0.4867)
# [Elapsed: 0:22:30] [RAM: 1498.8 MB] Epoch 270 | Train: 0.7938 | Val: 1.3599 (Acc: 0.4667)
# [Elapsed: 0:22:39] [RAM: 1498.8 MB] Epoch 280 | Train: 0.7602 | Val: 1.3830 (Acc: 0.4667)
# [Elapsed: 0:22:49] [RAM: 1498.8 MB] Epoch 290 | Train: 0.7807 | Val: 1.4238 (Acc: 0.4733)
# [Elapsed: 0:22:59] [RAM: 1498.8 MB] Epoch 300 | Train: 0.7785 | Val: 1.3918 (Acc: 0.4800)
# [Elapsed: 0:23:10] [RAM: 1498.8 MB] Epoch 310 | Train: 0.7768 | Val: 1.4094 (Acc: 0.4867)
# [Elapsed: 0:23:20] [RAM: 1498.8 MB] Epoch 320 | Train: 0.7684 | Val: 1.4136 (Acc: 0.4667)
# [Elapsed: 0:23:30] [RAM: 1498.8 MB] Epoch 330 | Train: 0.7750 | Val: 1.4967 (Acc: 0.4800)
# [Elapsed: 0:23:41] [RAM: 1498.8 MB] Epoch 340 | Train: 0.7809 | Val: 1.5325 (Acc: 0.4667)
# [Elapsed: 0:23:50] [RAM: 1498.8 MB] Epoch 350 | Train: 0.7608 | Val: 1.4966 (Acc: 0.4667)
# [Elapsed: 0:23:50] [RAM: 1498.8 MB] Training finished.
# [Elapsed: 0:23:50] [RAM: 1498.8 MB] Restoring best model from Epoch 30 with Val Loss 0.9336
#
# [Fold 4 FINAL RESULTS]
#    > Best Val Acc: 53.33%
#    > F1-Score:     0.5272
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:23:50] [RAM: 1498.8 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:23:51] [RAM: 1498.8 MB] Saved: embeddings_fold_4.npz
# [Elapsed: 0:23:52] [RAM: 1498.8 MB] Loading 'embeddings_fold_4.npz' for Evaluation...
#
#    [Fold 4 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 38.0%   | 28.1%   | 0.589    | 0.75s
#    SVM_RBF    | 37.3%   | 35.6%   | 0.547    | 0.70s
#    RF         | 44.7%   | 43.1%   | 0.656    | 0.81s
#    MLP        | 40.0%   | 39.1%   | 0.579    | 2.07s
#    >> KMeans ARI: 0.0007
#    >> Spectral ARI: -0.0036
#    ============================================================
#
# >> Running Stability Analysis for Fold 4...
#
# >> ] Running Analysis for Fold 4...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 53.33%
# [Elapsed: 0:23:57] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:23:57] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:23:57] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:23:57] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:23:57] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:23:57] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:23:58] [RAM: 1498.8 MB] Perturb Dataset...
# [Elapsed: 0:23:58] [RAM: 1498.8 MB] Perturb Dataset...
#
#    [Fold 4 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.5333   | 1.0000
#    add        | 5%      | 0.5533   | 1.0000
#    add        | 10%      | 0.5533   | 1.0000
#    add        | 15%      | 0.5467   | 0.9999
#    add        | 20%      | 0.5600   | 0.9999
#    remove     | 5%      | 0.5333   | 1.0000
#    remove     | 10%      | 0.5267   | 0.9994
#    remove     | 15%      | 0.5267   | 0.9984
#    remove     | 20%      | 0.4867   | 0.9979
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 5/10
# [Elapsed: 0:23:58] [RAM: 1498.8 MB] --- Fold 5: Initializing GIN ---
# [Elapsed: 0:23:58] [RAM: 1498.8 MB] Starting Training Loop...
# [Elapsed: 0:24:08] [RAM: 1498.8 MB] Epoch 010 | Train: 1.1702 | Val: 0.9921 (Acc: 0.5133)
# [Elapsed: 0:24:18] [RAM: 1498.8 MB] Epoch 020 | Train: 1.0214 | Val: 1.2900 (Acc: 0.4933)
# [Elapsed: 0:24:28] [RAM: 1498.8 MB] Epoch 030 | Train: 0.9980 | Val: 1.3789 (Acc: 0.4867)
# [Elapsed: 0:24:38] [RAM: 1498.8 MB] Epoch 040 | Train: 0.9625 | Val: 19.8965 (Acc: 0.5333)
# [Elapsed: 0:24:48] [RAM: 1498.8 MB] Epoch 050 | Train: 0.9162 | Val: 1.0434 (Acc: 0.4933)
# [Elapsed: 0:24:58] [RAM: 1498.8 MB] Epoch 060 | Train: 0.9085 | Val: 1.1881 (Acc: 0.5067)
# [Elapsed: 0:25:08] [RAM: 1498.8 MB] Epoch 070 | Train: 0.8910 | Val: 4.0947 (Acc: 0.4400)
# [Elapsed: 0:25:18] [RAM: 1498.8 MB] Epoch 080 | Train: 0.8865 | Val: 3.9651 (Acc: 0.4600)
# [Elapsed: 0:25:28] [RAM: 1498.8 MB] Epoch 090 | Train: 0.8633 | Val: 6.4098 (Acc: 0.4800)
# [Elapsed: 0:25:38] [RAM: 1498.8 MB] Epoch 100 | Train: 0.8950 | Val: 2.3330 (Acc: 0.4867)
# [Elapsed: 0:25:48] [RAM: 1498.8 MB] Epoch 110 | Train: 0.8444 | Val: 5.5111 (Acc: 0.4533)
# [Elapsed: 0:25:58] [RAM: 1498.9 MB] Epoch 120 | Train: 0.8450 | Val: 8.7161 (Acc: 0.4600)
# [Elapsed: 0:26:08] [RAM: 1498.9 MB] Epoch 130 | Train: 0.8427 | Val: 14.7880 (Acc: 0.4333)
# [Elapsed: 0:26:19] [RAM: 1498.9 MB] Epoch 140 | Train: 0.8362 | Val: 8.5262 (Acc: 0.4667)
# [Elapsed: 0:26:29] [RAM: 1498.9 MB] Epoch 150 | Train: 0.8061 | Val: 5.9272 (Acc: 0.4667)
# [Elapsed: 0:26:39] [RAM: 1498.9 MB] Epoch 160 | Train: 0.8190 | Val: 5.7387 (Acc: 0.4400)
# [Elapsed: 0:26:49] [RAM: 1498.9 MB] Epoch 170 | Train: 0.8230 | Val: 2.3556 (Acc: 0.4733)
# [Elapsed: 0:27:00] [RAM: 1498.9 MB] Epoch 180 | Train: 0.8010 | Val: 1.4927 (Acc: 0.4267)
# [Elapsed: 0:27:10] [RAM: 1498.9 MB] Epoch 190 | Train: 0.8106 | Val: 2.1070 (Acc: 0.4467)
# [Elapsed: 0:27:21] [RAM: 1498.9 MB] Epoch 200 | Train: 0.7911 | Val: 2.1486 (Acc: 0.4267)
# [Elapsed: 0:27:31] [RAM: 1498.9 MB] Epoch 210 | Train: 0.8000 | Val: 3.2277 (Acc: 0.4533)
# [Elapsed: 0:27:41] [RAM: 1498.9 MB] Epoch 220 | Train: 0.7889 | Val: 1.3110 (Acc: 0.4533)
# [Elapsed: 0:27:50] [RAM: 1498.9 MB] Epoch 230 | Train: 0.7911 | Val: 1.3300 (Acc: 0.4800)
# [Elapsed: 0:28:00] [RAM: 1498.9 MB] Epoch 240 | Train: 0.7949 | Val: 1.4700 (Acc: 0.4400)
# [Elapsed: 0:28:10] [RAM: 1498.9 MB] Epoch 250 | Train: 0.7838 | Val: 1.2948 (Acc: 0.4667)
# [Elapsed: 0:28:20] [RAM: 1498.9 MB] Epoch 260 | Train: 0.7837 | Val: 1.3538 (Acc: 0.4600)
# [Elapsed: 0:28:31] [RAM: 1498.9 MB] Epoch 270 | Train: 0.7663 | Val: 1.3610 (Acc: 0.4533)
# [Elapsed: 0:28:40] [RAM: 1498.9 MB] Epoch 280 | Train: 0.7669 | Val: 1.3825 (Acc: 0.4600)
# [Elapsed: 0:28:50] [RAM: 1498.9 MB] Epoch 290 | Train: 0.7934 | Val: 1.4042 (Acc: 0.4733)
# [Elapsed: 0:29:00] [RAM: 1498.9 MB] Epoch 300 | Train: 0.7620 | Val: 1.4196 (Acc: 0.4600)
# [Elapsed: 0:29:10] [RAM: 1498.9 MB] Epoch 310 | Train: 0.7724 | Val: 1.4454 (Acc: 0.4467)
# [Elapsed: 0:29:20] [RAM: 1498.9 MB] Epoch 320 | Train: 0.7670 | Val: 1.4049 (Acc: 0.4600)
# [Elapsed: 0:29:30] [RAM: 1498.9 MB] Epoch 330 | Train: 0.7762 | Val: 1.4266 (Acc: 0.4533)
# [Elapsed: 0:29:39] [RAM: 1498.9 MB] Epoch 340 | Train: 0.7654 | Val: 1.4082 (Acc: 0.4467)
# [Elapsed: 0:29:49] [RAM: 1498.9 MB] Epoch 350 | Train: 0.7526 | Val: 1.3845 (Acc: 0.4467)
# [Elapsed: 0:29:49] [RAM: 1498.9 MB] Training finished.
# [Elapsed: 0:29:49] [RAM: 1498.9 MB] Restoring best model from Epoch 27 with Val Loss 0.9808
#
# [Fold 5 FINAL RESULTS]
#    > Best Val Acc: 52.67%
#    > F1-Score:     0.5218
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:29:50] [RAM: 1498.9 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:29:50] [RAM: 1498.9 MB] Saved: embeddings_fold_5.npz
# [Elapsed: 0:29:51] [RAM: 1498.9 MB] Loading 'embeddings_fold_5.npz' for Evaluation...
#
#    [Fold 5 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 35.3%   | 23.7%   | 0.572    | 0.59s
#    SVM_RBF    | 27.3%   | 25.6%   | 0.503    | 1.06s
#    RF         | 46.7%   | 44.6%   | 0.614    | 1.30s
#    MLP        | 42.0%   | 38.8%   | 0.622    | 3.70s
#    >> KMeans ARI: 0.0030
#    >> Spectral ARI: -0.0004
#    ============================================================
#
# >> Running Stability Analysis for Fold 5...
#
# >> ] Running Analysis for Fold 5...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 52.67%
# [Elapsed: 0:29:58] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:29:58] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:29:58] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:29:58] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:29:58] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:29:58] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:29:58] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:29:59] [RAM: 1498.9 MB] Perturb Dataset...
#
#    [Fold 5 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.5267   | 1.0000
#    add        | 5%      | 0.5200   | 0.9999
#    add        | 10%      | 0.5200   | 0.9997
#    add        | 15%      | 0.5133   | 0.9985
#    add        | 20%      | 0.5333   | 0.9966
#    remove     | 5%      | 0.5067   | 1.0000
#    remove     | 10%      | 0.5067   | 0.9999
#    remove     | 15%      | 0.5333   | 0.9998
#    remove     | 20%      | 0.4733   | 0.9997
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 6/10
# [Elapsed: 0:29:59] [RAM: 1498.9 MB] --- Fold 6: Initializing GIN ---
# [Elapsed: 0:29:59] [RAM: 1498.9 MB] Starting Training Loop...
# [Elapsed: 0:30:09] [RAM: 1498.9 MB] Epoch 010 | Train: 1.3061 | Val: 1.0035 (Acc: 0.3867)
# [Elapsed: 0:30:19] [RAM: 1498.9 MB] Epoch 020 | Train: 1.0161 | Val: 9.3438 (Acc: 0.5000)
# [Elapsed: 0:30:29] [RAM: 1498.9 MB] Epoch 030 | Train: 0.9736 | Val: 2.6369 (Acc: 0.3867)
# [Elapsed: 0:30:39] [RAM: 1498.9 MB] Epoch 040 | Train: 0.9884 | Val: 0.9677 (Acc: 0.5200)
# [Elapsed: 0:30:49] [RAM: 1498.9 MB] Epoch 050 | Train: 0.9648 | Val: 17.5624 (Acc: 0.5000)
# [Elapsed: 0:30:59] [RAM: 1498.9 MB] Epoch 060 | Train: 0.9377 | Val: 4.3589 (Acc: 0.4600)
# [Elapsed: 0:31:09] [RAM: 1498.9 MB] Epoch 070 | Train: 0.9399 | Val: 5.0185 (Acc: 0.4600)
# [Elapsed: 0:31:19] [RAM: 1498.9 MB] Epoch 080 | Train: 0.9125 | Val: 3.3888 (Acc: 0.4733)
# [Elapsed: 0:31:28] [RAM: 1498.9 MB] Epoch 090 | Train: 0.8951 | Val: 9.2515 (Acc: 0.4533)
# [Elapsed: 0:31:38] [RAM: 1498.9 MB] Epoch 100 | Train: 0.9058 | Val: 0.9932 (Acc: 0.5067)
# [Elapsed: 0:31:48] [RAM: 1498.9 MB] Epoch 110 | Train: 0.8604 | Val: 3.0237 (Acc: 0.4867)
# [Elapsed: 0:31:58] [RAM: 1498.9 MB] Epoch 120 | Train: 0.8722 | Val: 2.9491 (Acc: 0.4800)
# [Elapsed: 0:32:08] [RAM: 1498.9 MB] Epoch 130 | Train: 0.8495 | Val: 1.0188 (Acc: 0.5133)
# [Elapsed: 0:32:17] [RAM: 1498.9 MB] Epoch 140 | Train: 0.8343 | Val: 2.1478 (Acc: 0.4933)
# [Elapsed: 0:32:27] [RAM: 1498.9 MB] Epoch 150 | Train: 0.8396 | Val: 1.8602 (Acc: 0.4867)
# [Elapsed: 0:32:37] [RAM: 1498.9 MB] Epoch 160 | Train: 0.8307 | Val: 1.0228 (Acc: 0.5000)
# [Elapsed: 0:32:47] [RAM: 1498.9 MB] Epoch 170 | Train: 0.8138 | Val: 1.0263 (Acc: 0.5067)
# [Elapsed: 0:32:57] [RAM: 1498.9 MB] Epoch 180 | Train: 0.8135 | Val: 1.3277 (Acc: 0.5067)
# [Elapsed: 0:33:07] [RAM: 1498.9 MB] Epoch 190 | Train: 0.8128 | Val: 1.0376 (Acc: 0.5200)
# [Elapsed: 0:33:16] [RAM: 1498.9 MB] Epoch 200 | Train: 0.8123 | Val: 1.0718 (Acc: 0.4733)
# [Elapsed: 0:33:26] [RAM: 1498.9 MB] Epoch 210 | Train: 0.7987 | Val: 1.0438 (Acc: 0.5000)
# [Elapsed: 0:33:36] [RAM: 1498.9 MB] Epoch 220 | Train: 0.8255 | Val: 1.0438 (Acc: 0.5000)
# [Elapsed: 0:33:46] [RAM: 1498.9 MB] Epoch 230 | Train: 0.8059 | Val: 1.0934 (Acc: 0.4933)
# [Elapsed: 0:33:56] [RAM: 1498.9 MB] Epoch 240 | Train: 0.8091 | Val: 1.0330 (Acc: 0.4933)
# [Elapsed: 0:34:06] [RAM: 1498.9 MB] Epoch 250 | Train: 0.7953 | Val: 1.1232 (Acc: 0.5000)
# [Elapsed: 0:34:16] [RAM: 1498.9 MB] Epoch 260 | Train: 0.7857 | Val: 1.0849 (Acc: 0.4867)
# [Elapsed: 0:34:25] [RAM: 1498.9 MB] Epoch 270 | Train: 0.7992 | Val: 1.0727 (Acc: 0.4933)
# [Elapsed: 0:34:35] [RAM: 1498.9 MB] Epoch 280 | Train: 0.7819 | Val: 1.0591 (Acc: 0.5000)
# [Elapsed: 0:34:45] [RAM: 1498.9 MB] Epoch 290 | Train: 0.7819 | Val: 1.0603 (Acc: 0.4933)
# [Elapsed: 0:34:55] [RAM: 1498.9 MB] Epoch 300 | Train: 0.7896 | Val: 1.6087 (Acc: 0.4667)
# [Elapsed: 0:35:04] [RAM: 1498.9 MB] Epoch 310 | Train: 0.7947 | Val: 1.1271 (Acc: 0.4867)
# [Elapsed: 0:35:14] [RAM: 1498.9 MB] Epoch 320 | Train: 0.7692 | Val: 1.1136 (Acc: 0.4733)
# [Elapsed: 0:35:24] [RAM: 1498.9 MB] Epoch 330 | Train: 0.7781 | Val: 1.0947 (Acc: 0.4800)
# [Elapsed: 0:35:34] [RAM: 1498.9 MB] Epoch 340 | Train: 0.7691 | Val: 1.0863 (Acc: 0.4800)
# [Elapsed: 0:35:44] [RAM: 1498.9 MB] Epoch 350 | Train: 0.7733 | Val: 1.1088 (Acc: 0.5000)
# [Elapsed: 0:35:44] [RAM: 1498.9 MB] Training finished.
# [Elapsed: 0:35:44] [RAM: 1498.9 MB] Restoring best model from Epoch 101 with Val Loss 0.9605
#
# [Fold 6 FINAL RESULTS]
#    > Best Val Acc: 48.67%
#    > F1-Score:     0.4681
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:35:44] [RAM: 1498.9 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:35:45] [RAM: 1498.9 MB] Saved: embeddings_fold_6.npz
# [Elapsed: 0:35:46] [RAM: 1498.9 MB] Loading 'embeddings_fold_6.npz' for Evaluation...
#
#    [Fold 6 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 47.3%   | 41.4%   | 0.686    | 0.61s
#    SVM_RBF    | 44.7%   | 42.3%   | 0.641    | 0.66s
#    RF         | 46.7%   | 43.9%   | 0.668    | 0.78s
#    MLP        | 50.7%   | 47.3%   | 0.693    | 2.20s
#    >> KMeans ARI: 0.0002
#    >> Spectral ARI: 0.0218
#    ============================================================
#
# >> Running Stability Analysis for Fold 6...
#
# >> ] Running Analysis for Fold 6...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 48.67%
# [Elapsed: 0:35:50] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:35:50] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:35:50] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:35:51] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:35:51] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:35:51] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:35:51] [RAM: 1498.9 MB] Perturb Dataset...
# [Elapsed: 0:35:51] [RAM: 1498.9 MB] Perturb Dataset...
#
#    [Fold 6 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.4867   | 1.0000
#    add        | 5%      | 0.5000   | 0.9994
#    add        | 10%      | 0.5133   | 0.9986
#    add        | 15%      | 0.5133   | 0.9981
#    add        | 20%      | 0.5000   | 0.9977
#    remove     | 5%      | 0.4933   | 0.9998
#    remove     | 10%      | 0.5000   | 0.9993
#    remove     | 15%      | 0.4800   | 0.9979
#    remove     | 20%      | 0.4867   | 0.9947
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 7/10
# [Elapsed: 0:35:51] [RAM: 1498.9 MB] --- Fold 7: Initializing GIN ---
# [Elapsed: 0:35:51] [RAM: 1498.9 MB] Starting Training Loop...
# [Elapsed: 0:36:01] [RAM: 1498.9 MB] Epoch 010 | Train: 1.3985 | Val: 1.0109 (Acc: 0.4600)
# [Elapsed: 0:36:11] [RAM: 1498.9 MB] Epoch 020 | Train: 1.1324 | Val: 7.4843 (Acc: 0.5467)
# [Elapsed: 0:36:21] [RAM: 1498.9 MB] Epoch 030 | Train: 0.9633 | Val: 0.9408 (Acc: 0.5267)
# [Elapsed: 0:36:31] [RAM: 1498.9 MB] Epoch 040 | Train: 0.9888 | Val: 30.2034 (Acc: 0.4733)
# [Elapsed: 0:36:41] [RAM: 1498.9 MB] Epoch 050 | Train: 0.9554 | Val: 14.5487 (Acc: 0.5067)
# [Elapsed: 0:36:51] [RAM: 1498.9 MB] Epoch 060 | Train: 0.9280 | Val: 13.1419 (Acc: 0.5000)
# [Elapsed: 0:37:01] [RAM: 1499.0 MB] Epoch 070 | Train: 0.9242 | Val: 29.6050 (Acc: 0.5267)
# [Elapsed: 0:37:11] [RAM: 1499.0 MB] Epoch 080 | Train: 0.8930 | Val: 63.5255 (Acc: 0.5000)
# [Elapsed: 0:37:21] [RAM: 1499.0 MB] Epoch 090 | Train: 0.9003 | Val: 83.9144 (Acc: 0.5200)
# [Elapsed: 0:37:31] [RAM: 1499.0 MB] Epoch 100 | Train: 0.8932 | Val: 37.7742 (Acc: 0.5200)
# [Elapsed: 0:37:40] [RAM: 1499.0 MB] Epoch 110 | Train: 0.8649 | Val: 63.3138 (Acc: 0.5267)
# [Elapsed: 0:37:50] [RAM: 1499.0 MB] Epoch 120 | Train: 0.8510 | Val: 63.9009 (Acc: 0.5267)
# [Elapsed: 0:38:00] [RAM: 1499.0 MB] Epoch 130 | Train: 0.8514 | Val: 130.4688 (Acc: 0.5200)
# [Elapsed: 0:38:10] [RAM: 1499.0 MB] Epoch 140 | Train: 0.8545 | Val: 55.1668 (Acc: 0.4933)
# [Elapsed: 0:38:20] [RAM: 1499.0 MB] Epoch 150 | Train: 0.8403 | Val: 124.0514 (Acc: 0.5333)
# [Elapsed: 0:38:30] [RAM: 1499.0 MB] Epoch 160 | Train: 0.8182 | Val: 229.9577 (Acc: 0.5267)
# [Elapsed: 0:38:40] [RAM: 1499.0 MB] Epoch 170 | Train: 0.8094 | Val: 24.3567 (Acc: 0.5133)
# [Elapsed: 0:38:50] [RAM: 1499.0 MB] Epoch 180 | Train: 0.8108 | Val: 12.3538 (Acc: 0.5400)
# [Elapsed: 0:39:00] [RAM: 1499.0 MB] Epoch 190 | Train: 0.8391 | Val: 37.4309 (Acc: 0.5133)
# [Elapsed: 0:39:10] [RAM: 1499.0 MB] Epoch 200 | Train: 0.8308 | Val: 69.0548 (Acc: 0.5400)
# [Elapsed: 0:39:20] [RAM: 1499.0 MB] Epoch 210 | Train: 0.8025 | Val: 182.3401 (Acc: 0.5400)
# [Elapsed: 0:39:29] [RAM: 1499.0 MB] Epoch 220 | Train: 0.8016 | Val: 126.5282 (Acc: 0.5600)
# [Elapsed: 0:39:39] [RAM: 1499.0 MB] Epoch 230 | Train: 0.7840 | Val: 13.9763 (Acc: 0.5467)
# [Elapsed: 0:39:49] [RAM: 1499.0 MB] Epoch 240 | Train: 0.7852 | Val: 32.4213 (Acc: 0.5467)
# [Elapsed: 0:39:59] [RAM: 1499.0 MB] Epoch 250 | Train: 0.7897 | Val: 6.4051 (Acc: 0.5600)
# [Elapsed: 0:40:09] [RAM: 1499.0 MB] Epoch 260 | Train: 0.7931 | Val: 7.2853 (Acc: 0.5467)
# [Elapsed: 0:40:19] [RAM: 1499.0 MB] Epoch 270 | Train: 0.8072 | Val: 5.1471 (Acc: 0.5333)
# [Elapsed: 0:40:28] [RAM: 1499.0 MB] Epoch 280 | Train: 0.7814 | Val: 2.6083 (Acc: 0.5467)
# [Elapsed: 0:40:38] [RAM: 1499.0 MB] Epoch 290 | Train: 0.8289 | Val: 1.0802 (Acc: 0.5400)
# [Elapsed: 0:40:48] [RAM: 1499.0 MB] Epoch 300 | Train: 0.7892 | Val: 1.6321 (Acc: 0.5467)
# [Elapsed: 0:40:58] [RAM: 1499.0 MB] Epoch 310 | Train: 0.7796 | Val: 1.0287 (Acc: 0.5667)
# [Elapsed: 0:41:08] [RAM: 1499.0 MB] Epoch 320 | Train: 0.7912 | Val: 1.0288 (Acc: 0.5667)
# [Elapsed: 0:41:18] [RAM: 1499.0 MB] Epoch 330 | Train: 0.7627 | Val: 1.1291 (Acc: 0.5533)
# [Elapsed: 0:41:27] [RAM: 1499.0 MB] Epoch 340 | Train: 0.7887 | Val: 1.2543 (Acc: 0.5667)
# [Elapsed: 0:41:37] [RAM: 1499.0 MB] Epoch 350 | Train: 0.7831 | Val: 1.0791 (Acc: 0.5533)
# [Elapsed: 0:41:37] [RAM: 1499.0 MB] Training finished.
# [Elapsed: 0:41:37] [RAM: 1499.0 MB] Restoring best model from Epoch 28 with Val Loss 0.9247
#
# [Fold 7 FINAL RESULTS]
#    > Best Val Acc: 53.33%
#    > F1-Score:     0.5107
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:41:38] [RAM: 1499.0 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:41:38] [RAM: 1499.0 MB] Saved: embeddings_fold_7.npz
# [Elapsed: 0:41:39] [RAM: 1499.0 MB] Loading 'embeddings_fold_7.npz' for Evaluation...
#
#    [Fold 7 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 38.0%   | 33.9%   | 0.527    | 0.51s
#    SVM_RBF    | 34.7%   | 33.1%   | 0.506    | 0.63s
#    RF         | 53.3%   | 52.3%   | 0.705    | 0.81s
#    MLP        | 39.3%   | 38.4%   | 0.586    | 3.25s
#    >> KMeans ARI: -0.0024
#    >> Spectral ARI: 0.0180
#    ============================================================
#
# >> Running Stability Analysis for Fold 7...
#
# >> ] Running Analysis for Fold 7...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 53.33%
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Perturb Dataset...
#
#    [Fold 7 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.5333   | 1.0000
#    add        | 5%      | 0.5333   | 1.0000
#    add        | 10%      | 0.5067   | 0.9995
#    add        | 15%      | 0.5200   | 0.9990
#    add        | 20%      | 0.5200   | 0.9987
#    remove     | 5%      | 0.5400   | 1.0000
#    remove     | 10%      | 0.5267   | 0.9999
#    remove     | 15%      | 0.5467   | 0.9998
#    remove     | 20%      | 0.5467   | 0.9993
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 8/10
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] --- Fold 8: Initializing GIN ---
# [Elapsed: 0:41:45] [RAM: 1499.0 MB] Starting Training Loop...
# [Elapsed: 0:41:55] [RAM: 1499.0 MB] Epoch 010 | Train: 1.8331 | Val: 2.1908 (Acc: 0.4133)
# [Elapsed: 0:42:04] [RAM: 1499.0 MB] Epoch 020 | Train: 0.9917 | Val: 3.4203 (Acc: 0.5200)
# [Elapsed: 0:42:14] [RAM: 1499.0 MB] Epoch 030 | Train: 0.9941 | Val: 1.0109 (Acc: 0.5333)
# [Elapsed: 0:42:24] [RAM: 1499.0 MB] Epoch 040 | Train: 0.9700 | Val: 1.4559 (Acc: 0.4867)
# [Elapsed: 0:42:34] [RAM: 1499.0 MB] Epoch 050 | Train: 0.9223 | Val: 11.0974 (Acc: 0.4333)
# [Elapsed: 0:42:44] [RAM: 1499.0 MB] Epoch 060 | Train: 0.9055 | Val: 6.2320 (Acc: 0.5200)
# [Elapsed: 0:42:53] [RAM: 1499.0 MB] Epoch 070 | Train: 0.8936 | Val: 6.1719 (Acc: 0.5533)
# [Elapsed: 0:43:03] [RAM: 1499.0 MB] Epoch 080 | Train: 0.9005 | Val: 6.8109 (Acc: 0.5533)
# [Elapsed: 0:43:13] [RAM: 1499.0 MB] Epoch 090 | Train: 0.8828 | Val: 13.4824 (Acc: 0.5133)
# [Elapsed: 0:43:23] [RAM: 1499.0 MB] Epoch 100 | Train: 0.9004 | Val: 0.9986 (Acc: 0.5667)
# [Elapsed: 0:43:33] [RAM: 1499.0 MB] Epoch 110 | Train: 0.8691 | Val: 1.3774 (Acc: 0.5467)
# [Elapsed: 0:43:42] [RAM: 1499.0 MB] Epoch 120 | Train: 0.8462 | Val: 1.8046 (Acc: 0.5400)
# [Elapsed: 0:43:52] [RAM: 1499.0 MB] Epoch 130 | Train: 0.8697 | Val: 3.0609 (Acc: 0.5333)
# [Elapsed: 0:44:01] [RAM: 1499.0 MB] Epoch 140 | Train: 0.8606 | Val: 1.1171 (Acc: 0.5333)
# [Elapsed: 0:44:11] [RAM: 1499.0 MB] Epoch 150 | Train: 0.8411 | Val: 3.2495 (Acc: 0.5333)
# [Elapsed: 0:44:21] [RAM: 1499.0 MB] Epoch 160 | Train: 0.8274 | Val: 3.1679 (Acc: 0.5267)
# [Elapsed: 0:44:31] [RAM: 1499.0 MB] Epoch 170 | Train: 0.8235 | Val: 2.9364 (Acc: 0.5133)
# [Elapsed: 0:44:40] [RAM: 1499.0 MB] Epoch 180 | Train: 0.8219 | Val: 1.8373 (Acc: 0.5133)
# [Elapsed: 0:44:50] [RAM: 1499.0 MB] Epoch 190 | Train: 0.8215 | Val: 2.4283 (Acc: 0.5267)
# [Elapsed: 0:45:00] [RAM: 1499.0 MB] Epoch 200 | Train: 0.7961 | Val: 1.1394 (Acc: 0.5333)
# [Elapsed: 0:45:10] [RAM: 1499.0 MB] Epoch 210 | Train: 0.8007 | Val: 1.1868 (Acc: 0.5333)
# [Elapsed: 0:45:20] [RAM: 1499.0 MB] Epoch 220 | Train: 0.8046 | Val: 1.1959 (Acc: 0.5267)
# [Elapsed: 0:45:29] [RAM: 1499.0 MB] Epoch 230 | Train: 0.8008 | Val: 2.2173 (Acc: 0.5267)
# [Elapsed: 0:45:39] [RAM: 1499.0 MB] Epoch 240 | Train: 0.7920 | Val: 1.1427 (Acc: 0.5333)
# [Elapsed: 0:45:49] [RAM: 1499.0 MB] Epoch 250 | Train: 0.7971 | Val: 1.9816 (Acc: 0.5267)
# [Elapsed: 0:45:59] [RAM: 1499.0 MB] Epoch 260 | Train: 0.7806 | Val: 2.9097 (Acc: 0.5200)
# [Elapsed: 0:46:09] [RAM: 1499.0 MB] Epoch 270 | Train: 0.7883 | Val: 1.4348 (Acc: 0.5267)
# [Elapsed: 0:46:19] [RAM: 1499.0 MB] Epoch 280 | Train: 0.7847 | Val: 1.5076 (Acc: 0.5133)
# [Elapsed: 0:46:28] [RAM: 1499.0 MB] Epoch 290 | Train: 0.7805 | Val: 1.9864 (Acc: 0.5133)
# [Elapsed: 0:46:38] [RAM: 1499.0 MB] Epoch 300 | Train: 0.7903 | Val: 1.2507 (Acc: 0.5200)
# [Elapsed: 0:46:48] [RAM: 1499.0 MB] Epoch 310 | Train: 0.8031 | Val: 1.2001 (Acc: 0.5333)
# [Elapsed: 0:46:58] [RAM: 1499.0 MB] Epoch 320 | Train: 0.7778 | Val: 1.4341 (Acc: 0.5133)
# [Elapsed: 0:47:07] [RAM: 1499.0 MB] Epoch 330 | Train: 0.7820 | Val: 1.4014 (Acc: 0.5267)
# [Elapsed: 0:47:17] [RAM: 1499.0 MB] Epoch 340 | Train: 0.7679 | Val: 1.4606 (Acc: 0.5067)
# [Elapsed: 0:47:28] [RAM: 1499.0 MB] Epoch 350 | Train: 0.7744 | Val: 1.2510 (Acc: 0.5267)
# [Elapsed: 0:47:28] [RAM: 1499.0 MB] Training finished.
# [Elapsed: 0:47:28] [RAM: 1499.0 MB] Restoring best model from Epoch 54 with Val Loss 0.9692
#
# [Fold 8 FINAL RESULTS]
#    > Best Val Acc: 53.33%
#    > F1-Score:     0.5241
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:47:28] [RAM: 1499.0 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:47:29] [RAM: 1499.0 MB] Saved: embeddings_fold_8.npz
# [Elapsed: 0:47:29] [RAM: 1499.0 MB] Loading 'embeddings_fold_8.npz' for Evaluation...
#
#    [Fold 8 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 52.0%   | 47.7%   | 0.678    | 0.57s
#    SVM_RBF    | 43.3%   | 42.1%   | 0.556    | 1.08s
#    RF         | 54.0%   | 51.7%   | 0.697    | 1.46s
#    MLP        | 53.3%   | 48.5%   | 0.725    | 3.30s
#    >> KMeans ARI: 0.0018
#    >> Spectral ARI: 0.0237
#    ============================================================
#
# >> Running Stability Analysis for Fold 8...
#
# >> ] Running Analysis for Fold 8...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 53.33%
# [Elapsed: 0:47:36] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:47:36] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:47:37] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:47:37] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:47:37] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:47:37] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:47:37] [RAM: 1499.0 MB] Perturb Dataset...
# [Elapsed: 0:47:37] [RAM: 1499.0 MB] Perturb Dataset...
#
#    [Fold 8 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.5333   | 1.0000
#    add        | 5%      | 0.5267   | 1.0000
#    add        | 10%      | 0.5400   | 0.9997
#    add        | 15%      | 0.5667   | 0.9992
#    add        | 20%      | 0.5333   | 0.9987
#    remove     | 5%      | 0.5400   | 1.0000
#    remove     | 10%      | 0.5267   | 0.9999
#    remove     | 15%      | 0.5400   | 0.9998
#    remove     | 20%      | 0.5533   | 0.9996
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 9/10
# [Elapsed: 0:47:37] [RAM: 1499.0 MB] --- Fold 9: Initializing GIN ---
# [Elapsed: 0:47:37] [RAM: 1499.0 MB] Starting Training Loop...
# [Elapsed: 0:47:47] [RAM: 1499.0 MB] Epoch 010 | Train: 1.4951 | Val: 15.6920 (Acc: 0.4000)
# [Elapsed: 0:47:58] [RAM: 1499.1 MB] Epoch 020 | Train: 1.1092 | Val: 0.9523 (Acc: 0.4867)
# [Elapsed: 0:48:07] [RAM: 1499.1 MB] Epoch 030 | Train: 1.0176 | Val: 15.2200 (Acc: 0.4667)
# [Elapsed: 0:48:17] [RAM: 1499.1 MB] Epoch 040 | Train: 0.9307 | Val: 8.4852 (Acc: 0.4867)
# [Elapsed: 0:48:27] [RAM: 1499.1 MB] Epoch 050 | Train: 0.9411 | Val: 10.5795 (Acc: 0.4133)
# [Elapsed: 0:48:37] [RAM: 1499.1 MB] Epoch 060 | Train: 0.9009 | Val: 3.2189 (Acc: 0.4800)
# [Elapsed: 0:48:47] [RAM: 1499.1 MB] Epoch 070 | Train: 0.9023 | Val: 1.6201 (Acc: 0.4800)
# [Elapsed: 0:48:57] [RAM: 1499.1 MB] Epoch 080 | Train: 0.8926 | Val: 15.8857 (Acc: 0.4467)
# [Elapsed: 0:49:07] [RAM: 1499.1 MB] Epoch 090 | Train: 0.8897 | Val: 2.5504 (Acc: 0.4067)
# [Elapsed: 0:49:17] [RAM: 1499.1 MB] Epoch 100 | Train: 0.9055 | Val: 22.5183 (Acc: 0.4733)
# [Elapsed: 0:49:27] [RAM: 1499.1 MB] Epoch 110 | Train: 0.8634 | Val: 26.2745 (Acc: 0.4667)
# [Elapsed: 0:49:37] [RAM: 1499.1 MB] Epoch 120 | Train: 0.8355 | Val: 28.5216 (Acc: 0.4467)
# [Elapsed: 0:49:47] [RAM: 1499.1 MB] Epoch 130 | Train: 0.8524 | Val: 34.7592 (Acc: 0.4867)
# [Elapsed: 0:49:56] [RAM: 1499.1 MB] Epoch 140 | Train: 0.8444 | Val: 4.1959 (Acc: 0.4533)
# [Elapsed: 0:50:06] [RAM: 1499.1 MB] Epoch 150 | Train: 0.8248 | Val: 25.0456 (Acc: 0.4733)
# [Elapsed: 0:50:16] [RAM: 1499.1 MB] Epoch 160 | Train: 0.8153 | Val: 28.1327 (Acc: 0.4467)
# [Elapsed: 0:50:26] [RAM: 1499.1 MB] Epoch 170 | Train: 0.8329 | Val: 34.0027 (Acc: 0.4800)
# [Elapsed: 0:50:36] [RAM: 1499.1 MB] Epoch 180 | Train: 0.8082 | Val: 2.9455 (Acc: 0.4267)
# [Elapsed: 0:50:46] [RAM: 1499.1 MB] Epoch 190 | Train: 0.8239 | Val: 9.5713 (Acc: 0.4267)
# [Elapsed: 0:50:55] [RAM: 1499.1 MB] Epoch 200 | Train: 0.8057 | Val: 3.3671 (Acc: 0.4533)
# [Elapsed: 0:51:05] [RAM: 1499.1 MB] Epoch 210 | Train: 0.8312 | Val: 11.4279 (Acc: 0.4600)
# [Elapsed: 0:51:15] [RAM: 1499.1 MB] Epoch 220 | Train: 0.7907 | Val: 6.0201 (Acc: 0.4600)
# [Elapsed: 0:51:25] [RAM: 1499.1 MB] Epoch 230 | Train: 0.8028 | Val: 1.3907 (Acc: 0.4600)
# [Elapsed: 0:51:35] [RAM: 1499.1 MB] Epoch 240 | Train: 0.7893 | Val: 3.2329 (Acc: 0.4733)
# [Elapsed: 0:51:46] [RAM: 1499.1 MB] Epoch 250 | Train: 0.7936 | Val: 1.3187 (Acc: 0.4667)
# [Elapsed: 0:51:55] [RAM: 1499.1 MB] Epoch 260 | Train: 0.8131 | Val: 1.6104 (Acc: 0.4667)
# [Elapsed: 0:52:05] [RAM: 1499.1 MB] Epoch 270 | Train: 0.7982 | Val: 1.2924 (Acc: 0.4600)
# [Elapsed: 0:52:15] [RAM: 1499.1 MB] Epoch 280 | Train: 0.7844 | Val: 1.3217 (Acc: 0.4867)
# [Elapsed: 0:52:25] [RAM: 1499.1 MB] Epoch 290 | Train: 0.7692 | Val: 1.3338 (Acc: 0.4600)
# [Elapsed: 0:52:36] [RAM: 1499.1 MB] Epoch 300 | Train: 0.7804 | Val: 1.3150 (Acc: 0.4733)
# [Elapsed: 0:52:46] [RAM: 1499.1 MB] Epoch 310 | Train: 0.7810 | Val: 1.3591 (Acc: 0.5067)
# [Elapsed: 0:52:55] [RAM: 1499.1 MB] Epoch 320 | Train: 0.7744 | Val: 1.3584 (Acc: 0.4667)
# [Elapsed: 0:53:05] [RAM: 1499.1 MB] Epoch 330 | Train: 0.7730 | Val: 1.3866 (Acc: 0.4667)
# [Elapsed: 0:53:16] [RAM: 1499.1 MB] Epoch 340 | Train: 0.7563 | Val: 1.3548 (Acc: 0.4867)
# [Elapsed: 0:53:26] [RAM: 1499.1 MB] Epoch 350 | Train: 0.7606 | Val: 1.5830 (Acc: 0.4600)
# [Elapsed: 0:53:26] [RAM: 1499.1 MB] Training finished.
# [Elapsed: 0:53:26] [RAM: 1499.1 MB] Restoring best model from Epoch 20 with Val Loss 0.9523
#
# [Fold 9 FINAL RESULTS]
#    > Best Val Acc: 48.67%
#    > F1-Score:     0.4417
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:53:26] [RAM: 1499.1 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:53:27] [RAM: 1499.1 MB] Saved: embeddings_fold_9.npz
# [Elapsed: 0:53:27] [RAM: 1499.1 MB] Loading 'embeddings_fold_9.npz' for Evaluation...
#
#    [Fold 9 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
#    SVM_Lin    | 40.0%   | 32.5%   | 0.618    | 0.54s
#    SVM_RBF    | 40.7%   | 39.8%   | 0.592    | 0.71s
#    RF         | 46.0%   | 45.9%   | 0.634    | 0.83s
#    MLP        | 46.7%   | 46.5%   | 0.697    | 3.50s
#    >> KMeans ARI: 0.0002
#    >> Spectral ARI: 0.0042
#    ============================================================
#
# >> Running Stability Analysis for Fold 9...
#
# >> ] Running Analysis for Fold 9...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 48.67%
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Perturb Dataset...
#
#    [Fold 9 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.4867   | 1.0000
#    add        | 5%      | 0.4867   | 0.9999
#    add        | 10%      | 0.5000   | 0.9998
#    add        | 15%      | 0.4800   | 0.9996
#    add        | 20%      | 0.4667   | 0.9994
#    remove     | 5%      | 0.4867   | 0.9999
#    remove     | 10%      | 0.5000   | 0.9998
#    remove     | 15%      | 0.4933   | 0.9996
#    remove     | 20%      | 0.5133   | 0.9992
#    ----------------------------------------
#
#
# ========================================
# STARTING FOLD 10/10
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] --- Fold 10: Initializing GIN ---
# [Elapsed: 0:53:34] [RAM: 1499.1 MB] Starting Training Loop...
# [Elapsed: 0:53:44] [RAM: 1499.1 MB] Epoch 010 | Train: 1.3953 | Val: 2.1509 (Acc: 0.4200)
# [Elapsed: 0:53:54] [RAM: 1499.1 MB] Epoch 020 | Train: 0.9931 | Val: 0.9968 (Acc: 0.5133)
# [Elapsed: 0:54:04] [RAM: 1499.1 MB] Epoch 030 | Train: 0.9968 | Val: 3.4396 (Acc: 0.4933)
# [Elapsed: 0:54:14] [RAM: 1499.1 MB] Epoch 040 | Train: 0.9527 | Val: 11.5349 (Acc: 0.4733)
# [Elapsed: 0:54:24] [RAM: 1499.1 MB] Epoch 050 | Train: 0.9392 | Val: 10.2368 (Acc: 0.4133)
# [Elapsed: 0:54:34] [RAM: 1499.1 MB] Epoch 060 | Train: 0.9064 | Val: 15.5795 (Acc: 0.4867)
# [Elapsed: 0:54:44] [RAM: 1499.1 MB] Epoch 070 | Train: 0.8793 | Val: 3.9173 (Acc: 0.4867)
# [Elapsed: 0:54:54] [RAM: 1499.1 MB] Epoch 080 | Train: 0.8980 | Val: 1.4665 (Acc: 0.4533)
# [Elapsed: 0:55:04] [RAM: 1499.1 MB] Epoch 090 | Train: 0.8935 | Val: 4.9681 (Acc: 0.5000)
# [Elapsed: 0:55:14] [RAM: 1499.1 MB] Epoch 100 | Train: 0.8876 | Val: 14.9920 (Acc: 0.4933)
# [Elapsed: 0:55:24] [RAM: 1499.1 MB] Epoch 110 | Train: 0.8878 | Val: 1.5880 (Acc: 0.5000)
# [Elapsed: 0:55:34] [RAM: 1499.1 MB] Epoch 120 | Train: 0.8494 | Val: 2.5072 (Acc: 0.5067)
# [Elapsed: 0:55:43] [RAM: 1499.1 MB] Epoch 130 | Train: 0.8636 | Val: 1.0093 (Acc: 0.5200)
# [Elapsed: 0:55:53] [RAM: 1499.1 MB] Epoch 140 | Train: 0.8598 | Val: 8.1521 (Acc: 0.5267)
# [Elapsed: 0:56:04] [RAM: 1499.1 MB] Epoch 150 | Train: 0.8582 | Val: 84.7879 (Acc: 0.4867)
# [Elapsed: 0:56:14] [RAM: 1499.1 MB] Epoch 160 | Train: 0.8181 | Val: 115.3422 (Acc: 0.5133)
# [Elapsed: 0:56:24] [RAM: 1499.1 MB] Epoch 170 | Train: 0.8227 | Val: 39.0837 (Acc: 0.5200)
# [Elapsed: 0:56:34] [RAM: 1499.1 MB] Epoch 180 | Train: 0.8155 | Val: 23.0491 (Acc: 0.5000)
# [Elapsed: 0:56:43] [RAM: 1499.1 MB] Epoch 190 | Train: 0.8074 | Val: 17.3724 (Acc: 0.4933)
# [Elapsed: 0:56:53] [RAM: 1499.1 MB] Epoch 200 | Train: 0.8234 | Val: 44.9365 (Acc: 0.5133)
# [Elapsed: 0:57:03] [RAM: 1499.1 MB] Epoch 210 | Train: 0.8057 | Val: 9.1004 (Acc: 0.5067)
# [Elapsed: 0:57:13] [RAM: 1499.1 MB] Epoch 220 | Train: 0.7995 | Val: 23.9809 (Acc: 0.5067)
# [Elapsed: 0:57:23] [RAM: 1499.1 MB] Epoch 230 | Train: 0.7969 | Val: 16.0492 (Acc: 0.5133)
# [Elapsed: 0:57:33] [RAM: 1499.1 MB] Epoch 240 | Train: 0.8040 | Val: 42.3309 (Acc: 0.5000)
# [Elapsed: 0:57:43] [RAM: 1499.1 MB] Epoch 250 | Train: 0.7925 | Val: 46.0181 (Acc: 0.5067)
# [Elapsed: 0:57:53] [RAM: 1499.1 MB] Epoch 260 | Train: 0.7848 | Val: 36.8745 (Acc: 0.5333)
# [Elapsed: 0:58:03] [RAM: 1499.1 MB] Epoch 270 | Train: 0.7960 | Val: 149.6708 (Acc: 0.5267)
# [Elapsed: 0:58:13] [RAM: 1499.1 MB] Epoch 280 | Train: 0.8096 | Val: 60.6070 (Acc: 0.5067)
# [Elapsed: 0:58:23] [RAM: 1499.1 MB] Epoch 290 | Train: 0.7797 | Val: 34.5409 (Acc: 0.5333)
# [Elapsed: 0:58:32] [RAM: 1499.1 MB] Epoch 300 | Train: 0.7933 | Val: 38.7891 (Acc: 0.5133)
# [Elapsed: 0:58:42] [RAM: 1499.1 MB] Epoch 310 | Train: 0.7914 | Val: 32.3222 (Acc: 0.5067)
# [Elapsed: 0:58:52] [RAM: 1499.1 MB] Epoch 320 | Train: 0.7910 | Val: 23.9315 (Acc: 0.5067)
# [Elapsed: 0:59:02] [RAM: 1499.1 MB] Epoch 330 | Train: 0.7877 | Val: 32.9811 (Acc: 0.5067)
# [Elapsed: 0:59:12] [RAM: 1499.1 MB] Epoch 340 | Train: 0.7771 | Val: 28.6381 (Acc: 0.5133)
# [Elapsed: 0:59:21] [RAM: 1499.1 MB] Epoch 350 | Train: 0.8024 | Val: 35.8756 (Acc: 0.4867)
# [Elapsed: 0:59:21] [RAM: 1499.1 MB] Training finished.
# [Elapsed: 0:59:21] [RAM: 1499.1 MB] Restoring best model from Epoch 111 with Val Loss 0.9631
#
# [Fold 10 FINAL RESULTS]
#    > Best Val Acc: 52.67%
#    > F1-Score:     0.5255
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:59:22] [RAM: 1499.1 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1350, 64)
# [Elapsed: 0:59:23] [RAM: 1499.1 MB] Saved: embeddings_fold_10.npz
# [Elapsed: 0:59:23] [RAM: 1499.1 MB] Loading 'embeddings_fold_10.npz' for Evaluation...
#
#    [Fold 10 Evaluation]
#    Model      | Acc      | F1       | AUC      | Time(s)
#    ------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/svm/_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#    SVM_Lin    | 38.0%   | 28.3%   | 0.554    | 0.61s
#    SVM_RBF    | 39.3%   | 38.7%   | 0.566    | 0.73s
#    RF         | 50.7%   | 50.2%   | 0.711    | 0.80s
#    MLP        | 44.0%   | 43.8%   | 0.606    | 1.81s
#    >> KMeans ARI: 0.0005
#    >> Spectral ARI: 0.0012
#    ============================================================
#
# >> Running Stability Analysis for Fold 10...
#
# >> ] Running Analysis for Fold 10...
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#    > Clean Baseline Acc: 52.67%
# [Elapsed: 0:59:28] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:59:28] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:59:28] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:59:28] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:59:28] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:59:28] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:59:28] [RAM: 1499.1 MB] Perturb Dataset...
# [Elapsed: 0:59:28] [RAM: 1499.1 MB] Perturb Dataset...
#
#    [Fold 10 Stability Report]
#    Mode       | Noise    | Acc      | CosSim
#    ----------------------------------------
#    Clean      | 0%       | 0.5267   | 1.0000
#    add        | 5%      | 0.5333   | 0.9995
#    add        | 10%      | 0.5267   | 0.9963
#    add        | 15%      | 0.5067   | 0.9941
#    add        | 20%      | 0.5133   | 0.9931
#    remove     | 5%      | 0.5133   | 0.9999
#    remove     | 10%      | 0.4933   | 0.9991
#    remove     | 15%      | 0.5267   | 0.9933
#    remove     | 20%      | 0.4733   | 0.9860
#    ----------------------------------------
#
#
# ============================================================
# FINAL AGGREGATED RESULTS
# ============================================================
# [Data] Saved per-fold results to experiment_results.csv
#
# --- INTERNAL GNN METRICS  ---
# Internal_GIN_Val_Acc     : 0.5127 ± 0.0315
# Internal_GIN_Val_F1      : 0.5006 ± 0.0374
# Internal_GIN_Val_AUC     : 0.5000 ± 0.0000
# ----------------------------------------
# --- EXTERNAL CLASSIFIER METRICS ---
# SVM_Lin_Train_Time       : 0.5903 ± 0.0659
# SVM_Lin_Gen_Time         : 0.0159 ± 0.0015
# SVM_Lin_Acc              : 0.3987 ± 0.0557
# SVM_Lin_F1               : 0.3131 ± 0.0794
# SVM_Lin_AUC              : 0.6021 ± 0.0551
# SVM_RBF_Train_Time       : 0.7622 ± 0.1653
# SVM_RBF_Gen_Time         : 0.0422 ± 0.0121
# SVM_RBF_Acc              : 0.3800 ± 0.0566
# SVM_RBF_F1               : 0.3671 ± 0.0556
# SVM_RBF_AUC              : 0.5584 ± 0.0517
# RF_Train_Time            : 0.9186 ± 0.2467
# RF_Gen_Time              : 0.0345 ± 0.0060
# RF_Acc                   : 0.4873 ± 0.0339
# RF_F1                    : 0.4756 ± 0.0358
# RF_AUC                   : 0.6679 ± 0.0369
# MLP_Train_Time           : 2.4239 ± 0.9608
# MLP_Gen_Time             : 0.0052 ± 0.0009
# MLP_Acc                  : 0.4267 ± 0.0649
# MLP_F1                   : 0.4115 ± 0.0542
# MLP_AUC                  : 0.6142 ± 0.0721
# KMeans_ARI               : 0.0016 ± 0.0046
# Spectral_ARI             : 0.0097 ± 0.0123
# GIN_Train_Time           : 348.2210 ± 3.3687
# GIN_Peak_RAM_MB          : 0.4789 ± 0.0143
# GIN_Gen_Time             : 0.7164 ± 0.1451
# Stab_Add_5               : 0.5140 ± 0.0324
# Stab_Add_10              : 0.5160 ± 0.0290
# Stab_Add_15              : 0.5100 ± 0.0368
# Stab_Add_20              : 0.5060 ± 0.0426
# Stab_Remove_5            : 0.5127 ± 0.0236
# Stab_Remove_10           : 0.5100 ± 0.0184
# Stab_Remove_15           : 0.5180 ± 0.0270
# Stab_Remove_20           : 0.5060 ± 0.0297
# [Data] Saved summary stats to final_stats.json
#
# [Visuals] Generating Final Performance Summary Plot with Error Bars...
# [Visuals] Saved final summary to final_performance.png
# [Visuals] Saved resource usage report to resource_usage.png
#
# ======================================================================
#       RESOURCE CONSUMPTION REPORT (Mean ± Std)
# ======================================================================
# Method     | Train Time (s)       | Gen Time (s)         | Peak RAM (MB)
# ---------------------------------------------------------------------------
# GIN        | 348.22 ± 3.37        | 0.72 ± 0.15          | 0.48 ± 0.01
# SVM_Lin    | 0.59 ± 0.07          | 0.02 ± 0.00          | -
# SVM_RBF    | 0.76 ± 0.17          | 0.04 ± 0.01          | -
# RF         | 0.92 ± 0.25          | 0.03 ± 0.01          | -
# MLP        | 2.42 ± 0.96          | 0.01 ± 0.00          | -
# [Visuals] Saved training curves: fold_training_curves.png
# [Visuals] Saved fold performance plot: fold_performance.png
# >> Generating Dual Stability Summary Plot to final_stability_bar_chart.png...
# !! WARNING: stability_detailed_ALL_FOLDS.csv not found. Cannot plot Cosine Similarity.
#
# >> Merging detailed stability reports...
# [Data] Saved master stability file: stability_detailed_ALL_FOLDS.csv
# >> Generating Robustness Curve for Model_Accuracy...
# [Plots] Saved robustness curve to robustness_model_acc.png
# >> Generating Robustness Curve for Cosine_Similarity...
# [Plots] Saved robustness curve to robustness_cosine_sim.png
#
# Pipeline Finished in 59.56 minutes.

# %%
# !zip -r /content/imdbsteplr64.zip /content/*.npz /content/*.csv /content/*.png /content/*.json /content/*.pth
# Out:
#   adding: content/embeddings_fold_10.npz (deflated 65%)
#   adding: content/embeddings_fold_1.npz (deflated 63%)
#   adding: content/embeddings_fold_2.npz (deflated 63%)
#   adding: content/embeddings_fold_3.npz (deflated 63%)
#   adding: content/embeddings_fold_4.npz (deflated 63%)
#   adding: content/embeddings_fold_5.npz (deflated 63%)
#   adding: content/embeddings_fold_6.npz (deflated 64%)
#   adding: content/embeddings_fold_7.npz (deflated 63%)
#   adding: content/embeddings_fold_8.npz (deflated 63%)
#   adding: content/embeddings_fold_9.npz (deflated 63%)
#   adding: content/experiment_results.csv (deflated 62%)
#   adding: content/stability_detailed_ALL_FOLDS.csv (deflated 72%)
#   adding: content/stability_fold_10_detailed.csv (deflated 56%)
#   adding: content/stability_fold_1_detailed.csv (deflated 56%)
#   adding: content/stability_fold_2_detailed.csv (deflated 52%)
#   adding: content/stability_fold_3_detailed.csv (deflated 54%)
#   adding: content/stability_fold_4_detailed.csv (deflated 55%)
#   adding: content/stability_fold_5_detailed.csv (deflated 54%)
#   adding: content/stability_fold_6_detailed.csv (deflated 50%)
#   adding: content/stability_fold_7_detailed.csv (deflated 54%)
#   adding: content/stability_fold_8_detailed.csv (deflated 52%)
#   adding: content/stability_fold_9_detailed.csv (deflated 53%)
#   adding: content/dataset_info.png (deflated 21%)
#   adding: content/final_performance.png (deflated 25%)
#   adding: content/fold_performance.png (deflated 12%)
#   adding: content/fold_training_curves.png (deflated 3%)
#   adding: content/learning_curve_fold_10.png (deflated 5%)
#   adding: content/learning_curve_fold_1.png (deflated 6%)
#   adding: content/learning_curve_fold_2.png (deflated 5%)
#   adding: content/learning_curve_fold_3.png (deflated 6%)
#   adding: content/learning_curve_fold_4.png (deflated 6%)
#   adding: content/learning_curve_fold_5.png (deflated 5%)
#   adding: content/learning_curve_fold_6.png (deflated 6%)
#   adding: content/learning_curve_fold_7.png (deflated 6%)
#   adding: content/learning_curve_fold_8.png (deflated 6%)
#   adding: content/learning_curve_fold_9.png (deflated 5%)
#   adding: content/pca_cluster_comparison_fold_1.png (deflated 12%)
#   adding: content/resource_usage.png (deflated 28%)
#   adding: content/robustness_cosine_sim.png (deflated 14%)
#   adding: content/robustness_model_acc.png (deflated 16%)
#   adding: content/final_stats.json (deflated 68%)
#   adding: content/model_fold_10.pth (deflated 11%)
#   adding: content/model_fold_1.pth (deflated 11%)
#   adding: content/model_fold_2.pth (deflated 11%)
#   adding: content/model_fold_3.pth (deflated 10%)
#   adding: content/model_fold_4.pth (deflated 11%)
#   adding: content/model_fold_5.pth (deflated 11%)
#   adding: content/model_fold_6.pth (deflated 11%)
#   adding: content/model_fold_7.pth (deflated 11%)
#   adding: content/model_fold_8.pth (deflated 11%)
#   adding: content/model_fold_9.pth (deflated 11%)

# %%
from google.colab import files

files.download('imdbsteplr64.zip')

# %%
# ==============================================================================
# CONFIGURATION
# ==============================================================================
DATASET_NAME = 'IMDB-MULTI'
run_pipeline(run_dataset_analysis=False, run_main_experiment=False, enable_stability=False, run_hyperparameter_tuning=True, n_folds=10)
# Out:
# STARTING PIPELINE
# Loading IMDB-MULTI with One-Hot Degree...
#
# ============================================================
# STARTING HYPERPARAMETER TUNING (Embedding Dimension)
# ============================================================
#
# »»» Testing Hidden Dimension: 16 «««
# [Elapsed: 0:01:19] [RAM: 1455.4 MB] --- Fold 1000: Initializing GIN ---
# [Elapsed: 0:01:19] [RAM: 1463.6 MB] Starting Training Loop...
# [Elapsed: 0:01:30] [RAM: 1463.6 MB] Epoch 010 | Train: 1.0714 | Val: 1.2668 (Acc: 0.4167)
# [Elapsed: 0:01:39] [RAM: 1463.7 MB] Epoch 020 | Train: 1.0032 | Val: 1.1492 (Acc: 0.4567)
# [Elapsed: 0:01:49] [RAM: 1463.7 MB] Epoch 030 | Train: 0.9572 | Val: 1.2662 (Acc: 0.4600)
# [Elapsed: 0:01:58] [RAM: 1463.7 MB] Epoch 040 | Train: 0.9210 | Val: 1.3563 (Acc: 0.4533)
# [Elapsed: 0:02:08] [RAM: 1463.7 MB] Epoch 050 | Train: 0.8962 | Val: 1.6088 (Acc: 0.4567)
# [Elapsed: 0:02:17] [RAM: 1463.7 MB] Epoch 060 | Train: 0.8949 | Val: 1.3196 (Acc: 0.4533)
# [Elapsed: 0:02:26] [RAM: 1463.8 MB] Epoch 070 | Train: 0.8888 | Val: 1.3366 (Acc: 0.4733)
# [Elapsed: 0:02:35] [RAM: 1463.8 MB] Epoch 080 | Train: 0.9013 | Val: 3.2407 (Acc: 0.4567)
# [Elapsed: 0:02:45] [RAM: 1463.8 MB] Epoch 090 | Train: 0.8765 | Val: 2.9364 (Acc: 0.4733)
# [Elapsed: 0:02:54] [RAM: 1463.8 MB] Epoch 100 | Train: 0.8801 | Val: 1.8219 (Acc: 0.4667)
# [Elapsed: 0:03:04] [RAM: 1463.8 MB] Epoch 110 | Train: 0.8376 | Val: 2.9314 (Acc: 0.4500)
# [Elapsed: 0:03:13] [RAM: 1463.8 MB] Epoch 120 | Train: 0.8959 | Val: 5.7435 (Acc: 0.4533)
# [Elapsed: 0:03:23] [RAM: 1463.9 MB] Epoch 130 | Train: 0.8427 | Val: 3.8806 (Acc: 0.4567)
# [Elapsed: 0:03:32] [RAM: 1463.9 MB] Epoch 140 | Train: 0.8452 | Val: 4.4386 (Acc: 0.4733)
# [Elapsed: 0:03:42] [RAM: 1463.9 MB] Epoch 150 | Train: 0.8344 | Val: 2.0694 (Acc: 0.4500)
# [Elapsed: 0:03:42] [RAM: 1463.9 MB] Training finished.
# [Elapsed: 0:03:42] [RAM: 1463.9 MB] Restoring best model from Epoch 9 with Val Loss 1.0264
#
# [Fold 1000 FINAL RESULTS]
#    > Best Val Acc: 46.33%
#    > F1-Score:     0.4200
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:03:42] [RAM: 1467.4 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1200, 16)
# [Elapsed: 0:03:43] [RAM: 1467.4 MB] Saved: tuning_dim_16.npz
# »»» Testing Hidden Dimension: 32 «««
# [Elapsed: 0:03:43] [RAM: 1472.1 MB] --- Fold 1000: Initializing GIN ---
# [Elapsed: 0:03:43] [RAM: 1473.8 MB] Starting Training Loop...
# [Elapsed: 0:03:53] [RAM: 1487.2 MB] Epoch 010 | Train: 1.2838 | Val: 4.7951 (Acc: 0.4333)
# [Elapsed: 0:04:02] [RAM: 1487.3 MB] Epoch 020 | Train: 1.0985 | Val: 1.0088 (Acc: 0.4667)
# [Elapsed: 0:04:13] [RAM: 1487.3 MB] Epoch 030 | Train: 0.9377 | Val: 1.0094 (Acc: 0.4200)
# [Elapsed: 0:04:22] [RAM: 1487.4 MB] Epoch 040 | Train: 0.9216 | Val: 1.0248 (Acc: 0.4333)
# [Elapsed: 0:04:32] [RAM: 1487.4 MB] Epoch 050 | Train: 0.9599 | Val: 1.4909 (Acc: 0.4367)
# [Elapsed: 0:04:42] [RAM: 1487.4 MB] Epoch 060 | Train: 0.8817 | Val: 1.5361 (Acc: 0.4700)
# [Elapsed: 0:04:50] [RAM: 1487.4 MB] Epoch 070 | Train: 0.8734 | Val: 2.3901 (Acc: 0.4600)
# [Elapsed: 0:05:00] [RAM: 1487.4 MB] Epoch 080 | Train: 0.8735 | Val: 3.6781 (Acc: 0.4633)
# [Elapsed: 0:05:09] [RAM: 1487.5 MB] Epoch 090 | Train: 0.8504 | Val: 11.8731 (Acc: 0.4467)
# [Elapsed: 0:05:19] [RAM: 1487.5 MB] Epoch 100 | Train: 0.8601 | Val: 2.0490 (Acc: 0.4600)
# [Elapsed: 0:05:27] [RAM: 1487.5 MB] Epoch 110 | Train: 0.8347 | Val: 1.2455 (Acc: 0.4633)
# [Elapsed: 0:05:37] [RAM: 1487.5 MB] Epoch 120 | Train: 0.8316 | Val: 5.3363 (Acc: 0.4600)
# [Elapsed: 0:05:46] [RAM: 1487.5 MB] Epoch 130 | Train: 0.8228 | Val: 17.1483 (Acc: 0.4633)
# [Elapsed: 0:05:56] [RAM: 1487.5 MB] Epoch 140 | Train: 0.8061 | Val: 1.4301 (Acc: 0.4733)
# [Elapsed: 0:06:06] [RAM: 1487.5 MB] Epoch 150 | Train: 0.8144 | Val: 2.8219 (Acc: 0.4767)
# [Elapsed: 0:06:06] [RAM: 1487.5 MB] Training finished.
# [Elapsed: 0:06:06] [RAM: 1487.5 MB] Restoring best model from Epoch 29 with Val Loss 0.9867
#
# [Fold 1000 FINAL RESULTS]
#    > Best Val Acc: 47.00%
#    > F1-Score:     0.4531
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:06:06] [RAM: 1487.8 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1200, 32)
# [Elapsed: 0:06:06] [RAM: 1487.8 MB] Saved: tuning_dim_32.npz
# »»» Testing Hidden Dimension: 64 «««
# [Elapsed: 0:06:07] [RAM: 1492.3 MB] --- Fold 1000: Initializing GIN ---
# [Elapsed: 0:06:07] [RAM: 1493.0 MB] Starting Training Loop...
# [Elapsed: 0:06:17] [RAM: 1493.3 MB] Epoch 010 | Train: 1.3999 | Val: 3.2695 (Acc: 0.4167)
# [Elapsed: 0:06:26] [RAM: 1493.3 MB] Epoch 020 | Train: 1.0666 | Val: 1.0414 (Acc: 0.4833)
# [Elapsed: 0:06:36] [RAM: 1493.3 MB] Epoch 030 | Train: 1.0021 | Val: 1.2414 (Acc: 0.4600)
# [Elapsed: 0:06:45] [RAM: 1493.3 MB] Epoch 040 | Train: 0.9222 | Val: 0.9871 (Acc: 0.4633)
# [Elapsed: 0:06:55] [RAM: 1493.3 MB] Epoch 050 | Train: 0.9331 | Val: 1.0069 (Acc: 0.4633)
# [Elapsed: 0:07:04] [RAM: 1493.3 MB] Epoch 060 | Train: 0.8949 | Val: 1.0382 (Acc: 0.4767)
# [Elapsed: 0:07:13] [RAM: 1493.3 MB] Epoch 070 | Train: 0.8746 | Val: 1.0136 (Acc: 0.4733)
# [Elapsed: 0:07:23] [RAM: 1493.3 MB] Epoch 080 | Train: 0.8592 | Val: 4.5782 (Acc: 0.4633)
# [Elapsed: 0:07:33] [RAM: 1493.3 MB] Epoch 090 | Train: 0.8733 | Val: 1.0688 (Acc: 0.4767)
# [Elapsed: 0:07:42] [RAM: 1493.3 MB] Epoch 100 | Train: 0.8600 | Val: 1.1064 (Acc: 0.4833)
# [Elapsed: 0:07:51] [RAM: 1493.3 MB] Epoch 110 | Train: 0.8251 | Val: 1.1223 (Acc: 0.4667)
# [Elapsed: 0:08:01] [RAM: 1493.3 MB] Epoch 120 | Train: 0.8299 | Val: 1.0898 (Acc: 0.4833)
# [Elapsed: 0:08:10] [RAM: 1493.3 MB] Epoch 130 | Train: 0.8381 | Val: 1.0981 (Acc: 0.5000)
# [Elapsed: 0:08:20] [RAM: 1493.3 MB] Epoch 140 | Train: 0.8198 | Val: 1.1289 (Acc: 0.4933)
# [Elapsed: 0:08:30] [RAM: 1493.3 MB] Epoch 150 | Train: 0.8130 | Val: 2.1940 (Acc: 0.4400)
# [Elapsed: 0:08:30] [RAM: 1493.3 MB] Training finished.
# [Elapsed: 0:08:30] [RAM: 1493.3 MB] Restoring best model from Epoch 34 with Val Loss 0.9816
#
# [Fold 1000 FINAL RESULTS]
#    > Best Val Acc: 47.67%
#    > F1-Score:     0.4242
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:08:30] [RAM: 1493.5 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1200, 64)
# [Elapsed: 0:08:30] [RAM: 1493.5 MB] Saved: tuning_dim_64.npz
# »»» Testing Hidden Dimension: 128 «««
# [Elapsed: 0:08:31] [RAM: 1498.1 MB] --- Fold 1000: Initializing GIN ---
# [Elapsed: 0:08:31] [RAM: 1498.1 MB] Starting Training Loop...
# [Elapsed: 0:08:41] [RAM: 1498.1 MB] Epoch 010 | Train: 1.8775 | Val: 1.1309 (Acc: 0.4367)
# [Elapsed: 0:08:50] [RAM: 1498.1 MB] Epoch 020 | Train: 1.2816 | Val: 1.8878 (Acc: 0.4533)
# [Elapsed: 0:09:00] [RAM: 1498.1 MB] Epoch 030 | Train: 1.0044 | Val: 1.0211 (Acc: 0.4367)
# [Elapsed: 0:09:10] [RAM: 1498.1 MB] Epoch 040 | Train: 0.9439 | Val: 2.1573 (Acc: 0.4533)
# [Elapsed: 0:09:20] [RAM: 1498.1 MB] Epoch 050 | Train: 0.9354 | Val: 233.3549 (Acc: 0.4633)
# [Elapsed: 0:09:29] [RAM: 1498.1 MB] Epoch 060 | Train: 0.8905 | Val: 1.0919 (Acc: 0.4667)
# [Elapsed: 0:09:38] [RAM: 1498.1 MB] Epoch 070 | Train: 0.8680 | Val: 3.8869 (Acc: 0.4733)
# [Elapsed: 0:09:48] [RAM: 1498.1 MB] Epoch 080 | Train: 0.8633 | Val: 8.5314 (Acc: 0.4600)
# [Elapsed: 0:09:58] [RAM: 1498.1 MB] Epoch 090 | Train: 0.8667 | Val: 108.4046 (Acc: 0.4600)
# [Elapsed: 0:10:08] [RAM: 1498.1 MB] Epoch 100 | Train: 0.8863 | Val: 7.7297 (Acc: 0.4533)
# [Elapsed: 0:10:17] [RAM: 1498.1 MB] Epoch 110 | Train: 0.8250 | Val: 21.9379 (Acc: 0.4433)
# [Elapsed: 0:10:26] [RAM: 1498.1 MB] Epoch 120 | Train: 0.8068 | Val: 48.4847 (Acc: 0.4633)
# [Elapsed: 0:10:36] [RAM: 1498.1 MB] Epoch 130 | Train: 0.8175 | Val: 30.2200 (Acc: 0.4367)
# [Elapsed: 0:10:46] [RAM: 1498.1 MB] Epoch 140 | Train: 0.7997 | Val: 7.8152 (Acc: 0.4567)
# [Elapsed: 0:10:55] [RAM: 1498.1 MB] Epoch 150 | Train: 0.8006 | Val: 11.2969 (Acc: 0.4733)
# [Elapsed: 0:10:55] [RAM: 1498.1 MB] Training finished.
# [Elapsed: 0:10:55] [RAM: 1498.1 MB] Restoring best model from Epoch 15 with Val Loss 0.9881
#
# [Fold 1000 FINAL RESULTS]
#    > Best Val Acc: 49.67%
#    > F1-Score:     0.4910
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:10:56] [RAM: 1498.1 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1200, 128)
# [Elapsed: 0:10:56] [RAM: 1498.1 MB] Saved: tuning_dim_128.npz
# »»» Testing Hidden Dimension: 256 «««
# [Elapsed: 0:10:57] [RAM: 1498.1 MB] --- Fold 1000: Initializing GIN ---
# [Elapsed: 0:10:57] [RAM: 1498.1 MB] Starting Training Loop...
# [Elapsed: 0:11:07] [RAM: 1498.2 MB] Epoch 010 | Train: 1.6475 | Val: 7.0385 (Acc: 0.3833)
# [Elapsed: 0:11:16] [RAM: 1498.2 MB] Epoch 020 | Train: 1.4162 | Val: 30.5063 (Acc: 0.4033)
# [Elapsed: 0:11:26] [RAM: 1498.2 MB] Epoch 030 | Train: 1.0989 | Val: 2.9504 (Acc: 0.4500)
# [Elapsed: 0:11:36] [RAM: 1498.2 MB] Epoch 040 | Train: 1.1798 | Val: 89.2714 (Acc: 0.4600)
# [Elapsed: 0:11:46] [RAM: 1498.2 MB] Epoch 050 | Train: 1.0102 | Val: 16.1835 (Acc: 0.4500)
# [Elapsed: 0:11:55] [RAM: 1498.2 MB] Epoch 060 | Train: 0.9156 | Val: 12.7213 (Acc: 0.4300)
# [Elapsed: 0:12:05] [RAM: 1498.2 MB] Epoch 070 | Train: 0.9246 | Val: 50.1980 (Acc: 0.4467)
# [Elapsed: 0:12:14] [RAM: 1498.2 MB] Epoch 080 | Train: 0.8805 | Val: 110.6617 (Acc: 0.4267)
# [Elapsed: 0:12:24] [RAM: 1498.2 MB] Epoch 090 | Train: 0.8816 | Val: 152.8375 (Acc: 0.4233)
# [Elapsed: 0:12:34] [RAM: 1498.2 MB] Epoch 100 | Train: 0.8546 | Val: 229.6291 (Acc: 0.4533)
# [Elapsed: 0:12:44] [RAM: 1498.2 MB] Epoch 110 | Train: 0.8424 | Val: 96.4627 (Acc: 0.4433)
# [Elapsed: 0:12:53] [RAM: 1498.2 MB] Epoch 120 | Train: 0.8126 | Val: 83.0729 (Acc: 0.4533)
# [Elapsed: 0:13:03] [RAM: 1498.2 MB] Epoch 130 | Train: 0.8264 | Val: 39.2854 (Acc: 0.4667)
# [Elapsed: 0:13:13] [RAM: 1498.2 MB] Epoch 140 | Train: 0.8445 | Val: 10.9141 (Acc: 0.4667)
# [Elapsed: 0:13:23] [RAM: 1498.2 MB] Epoch 150 | Train: 0.8203 | Val: 10.3868 (Acc: 0.4767)
# [Elapsed: 0:13:23] [RAM: 1498.2 MB] Training finished.
# [Elapsed: 0:13:23] [RAM: 1498.2 MB] Restoring best model from Epoch 31 with Val Loss 1.0201
#
# [Fold 1000 FINAL RESULTS]
#    > Best Val Acc: 45.33%
#    > F1-Score:     0.4229
#    > AUC:          0.5000
# ----------------------------------------
# [Elapsed: 0:13:23] [RAM: 1498.2 MB] Extracting embeddings...
#    > Generated Embedding Dimensions: (1200, 256)
# [Elapsed: 0:13:23] [RAM: 1498.2 MB] Saved: tuning_dim_256.npz
# [Plot] Saved tuning tradeoff to tuning_tradeoff_plot.png
#
# [Tuning] Completed. Check 'tuning_tradeoff_plot.png'.
#
# Pipeline Finished in 12.11 minutes.
